# %%
import xmltodict
import os,sys
sys.path.append("../..")
sys.path.append("../../xsdviz")
import treepath.treepath as tp
from treepath.treepath import TreePath

from functools import reduce

import operator

from collections import Counter
from itertools import chain

import pandas as pd

# %%
#with open("customer.xsd", "r") as xsdf:
filename = "pacs.008.001.09.xsd"
#filename = "2012_04_XMLSchema.xsd"
#filename = "test copy.xsd"

with open(filename, "r") as xsdf:
    customer_xsd = xsdf.read()
cust_d = xmltodict.parse(customer_xsd)

# %%
def access_dict(d,p):
    return reduce(operator.getitem, p , d)

def isnumeric(v):
    return isinstance(v, (int, float, complex)) and not isinstance(v, bool)

# %%
cust_tp = tp.TreePath(cust_d)

# %%
import xsdparse

# %%
primitives_set= {'xs:duration','xs:dateTime','xs:time','xs:date','xs:gYearMonth','xs:gYear',
                'xs:gMonthDay','xs:gDay','xs:gMonth','xs:string','xs:boolean','xs:base64Binary',
                'xs:hexBinary','xs:float','xs:decimal','xs:integer','xs:nonPositiveInteger',
                'xs:negativeInteger','xs:int','xs:short','xs:byte','xs:nonNegativeInteger',
                'xs:unsignedLong','xs:positiveInteger','xs:unsignedInt','xs:unsignedShort',
                'xs:unsignedByte','xs:double','xs:anyURI','xs:QName','xs:NOTATION'}

nameable_xsd_elements = {"xs:attribute", "xs:attributeGroup","xs:complexType", "xs:element", 
                         "xs:group", "xs:key", "xs:keyref", "xs:notation", "xs:simpleType", 
                         "xs:unique", 'xs:primitiveType'}

ref_set = {"xs:attribute", "xs:attributeGroup", "xs:element", "xs:group", }
type_definition_set = {"xs:complexType", "xs:simpleType", "xs:primitiveType" }

# %%
type_definition_set
# Out:
# {'xs:complexType', 'xs:primitiveType', 'xs:simpleType'}

# %%
# Process XSD into ERD task steps
#1 Load XSD into malleable format

#2 Extract named objects

#3 Extract objects requiring references

#4 Loop over 3, updating object from #1 such that all named objects
#  are complete without any remaining reference updates. 

#5 Extract objects that define types, extensions and restrictions

#6 Reduce singular extensions and restrictions down to their singular/primitive types

#7 Identify objects that describe sequences and other multi-part objects 
#  and associate them with a named parent-type/element

#8 Create tree of joined sequences so as to result in a workable ERD with entities and joins
#  This tree would consist of nodes consisting of multi-part sequences, and elemental
#  types that themselves are pointers to other single-or-multi part sequences.

# %%
# Given a tree obj, and some child-tag used to identify nodes within that tree
# build an index used to link paths to their assigned names. 
# Since there's no guarantee of name-uniqueness, each name can refer to 
# one or more paths.

def build_path_index(obj, index_tag="@name"):
    index_d={}
    def store(k,v):
        if k in index_d:
            index_d[k].append(v)
        else:
            index_d[k]=[v]

    for p in TreePath._iterPaths(obj):
        if p[-1]==index_tag:
            #print(p)
            store(access_dict(obj,p), p[:-1])
    return index_d


# Querying the pre-built path_index (see build_path_index) on some key value, 
# choose the path that most closely matches a source_path provided. 
# In practice, this means returning the name most likely to be in scope, 
# when there's some ambiguity in terms of which name to pick.
def return_closest_path_match(path_index_d, key, source_path):

    cand_paths = path_index_d.get(key)
    score_paths = []
    for e,p in enumerate(cand_paths):
        matching_path = TreePath._shortest_common_path([p, source_path])
        score_paths.append( (len(matching_path), len(source_path)-len(matching_path) ) )
    #print(cand_paths, score_paths)
    return cand_paths[score_paths.index(sorted([s for s in score_paths], key=lambda x : (x[0], x[1]))[-1])]

# %%
# 1) Get the things
#named_things = [p[:-1] for p in TreePath._iterPaths(cust_d) if p[-1]=="@name"]
def gen_labelled_path_dict(info_d, index_tag="@name"):
    things={}
    for name, paths in build_path_index(info_d, index_tag=index_tag).items():
        things[name]=[]
        for path in paths:
            for e,path_element in enumerate(path[::-1]):
                if path_element in nameable_xsd_elements:
                    thing_type=path_element
                    things[name].append((thing_type, path))
                    break
                else:
                    pass
                    
    return things

prims = [{"@name":t} for t in primitives_set]
cust_d['xs:schema']['xs:primitiveType']=prims

named_things=gen_labelled_path_dict(cust_d, index_tag="@name")
things_requiring_reference = build_path_index(cust_d, index_tag="@ref")

#for k in things_requiring_reference:
#    print (k, named_things[k], things_requiring_reference[k])

#referred_things = [p[:-1] for p in TreePath._iterPaths(cust_d) if p[-1]=="@ref"]
#len(named_things),len(referred_things)

# %%
all_named_types = set()
named_other_things = set()

for k,v in named_things.items():
    for vv in v:
        if vv[0] in type_definition_set:
            
            all_named_types.add((k, vv[0], tuple(vv[1])))
        else:
            named_other_things.add((k, vv[0], tuple(vv[1])))

            
all_named_types # these will become terminal nodes for type-matching.
# Out:
# {('AccountIdentification4Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 0)),
#  ('AccountSchemeName1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 1)),
#  ('ActiveCurrencyAndAmount',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 2)),
#  ('ActiveCurrencyAndAmount_SimpleType',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 0)),
#  ('ActiveCurrencyCode', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 1)),
#  ('ActiveOrHistoricCurrencyAndAmount',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 3)),
#  ('ActiveOrHistoricCurrencyAndAmount_SimpleType',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 2)),
#  ('ActiveOrHistoricCurrencyCode',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 3)),
#  ('AddressType2Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 4)),
#  ('AddressType3Choice', 'xs:complexType', ('xs:schema', 'xs:complexType', 4)),
#  ('AnyBICDec2014Identifier',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 5)),
#  ('BICFIDec2014Identifier',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 6)),
#  ('BaseOneRate', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 7)),
#  ('BatchBookingIndicator', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 8)),
#  ('BranchAndFinancialInstitutionIdentification6',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 5)),
#  ('BranchData3', 'xs:complexType', ('xs:schema', 'xs:complexType', 6)),
#  ('CashAccount38', 'xs:complexType', ('xs:schema', 'xs:complexType', 7)),
#  ('CashAccountType2Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 8)),
#  ('CategoryPurpose1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 9)),
#  ('ChargeBearerType1Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 9)),
#  ('Charges7', 'xs:complexType', ('xs:schema', 'xs:complexType', 10)),
#  ('ClearingChannel2Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 10)),
#  ('ClearingSystemIdentification2Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 11)),
#  ('ClearingSystemIdentification3Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 12)),
#  ('ClearingSystemMemberIdentification2',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 13)),
#  ('Contact4', 'xs:complexType', ('xs:schema', 'xs:complexType', 14)),
#  ('CountryCode', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 11)),
#  ('CreditDebitCode', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 12)),
#  ('CreditTransferMandateData1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 15)),
#  ('CreditTransferTransaction43',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 16)),
#  ('CreditorReferenceInformation2',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 17)),
#  ('CreditorReferenceType1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 18)),
#  ('CreditorReferenceType2',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 19)),
#  ('DateAndPlaceOfBirth1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 20)),
#  ('DatePeriod2', 'xs:complexType', ('xs:schema', 'xs:complexType', 21)),
#  ('DecimalNumber', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 13)),
#  ('DiscountAmountAndType1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 22)),
#  ('DiscountAmountType1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 23)),
#  ('Document', 'xs:complexType', ('xs:schema', 'xs:complexType', 24)),
#  ('DocumentAdjustment1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 25)),
#  ('DocumentLineIdentification1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 26)),
#  ('DocumentLineInformation1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 27)),
#  ('DocumentLineType1', 'xs:complexType', ('xs:schema', 'xs:complexType', 28)),
#  ('DocumentLineType1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 29)),
#  ('DocumentType3Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 14)),
#  ('DocumentType6Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 15)),
#  ('Exact2NumericText', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 16)),
#  ('Exact4AlphaNumericText',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 17)),
#  ('ExternalAccountIdentification1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 18)),
#  ('ExternalCashAccountType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 19)),
#  ('ExternalCashClearingSystem1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 20)),
#  ('ExternalCategoryPurpose1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 21)),
#  ('ExternalClearingSystemIdentification1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 22)),
#  ('ExternalCreditorAgentInstruction1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 23)),
#  ('ExternalDiscountAmountType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 24)),
#  ('ExternalDocumentLineType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 25)),
#  ('ExternalFinancialInstitutionIdentification1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 26)),
#  ('ExternalGarnishmentType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 27)),
#  ('ExternalLocalInstrument1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 28)),
#  ('ExternalMandateSetupReason1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 29)),
#  ('ExternalOrganisationIdentification1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 30)),
#  ('ExternalPersonIdentification1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 31)),
#  ('ExternalProxyAccountType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 32)),
#  ('ExternalPurpose1Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 33)),
#  ('ExternalServiceLevel1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 34)),
#  ('ExternalTaxAmountType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 35)),
#  ('FIToFICustomerCreditTransferV09',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 30)),
#  ('FinancialIdentificationSchemeName1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 31)),
#  ('FinancialInstitutionIdentification18',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 32)),
#  ('Frequency36Choice', 'xs:complexType', ('xs:schema', 'xs:complexType', 33)),
#  ('Frequency6Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 36)),
#  ('FrequencyAndMoment1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 34)),
#  ('FrequencyPeriod1', 'xs:complexType', ('xs:schema', 'xs:complexType', 35)),
#  ('Garnishment3', 'xs:complexType', ('xs:schema', 'xs:complexType', 36)),
#  ('GarnishmentType1', 'xs:complexType', ('xs:schema', 'xs:complexType', 37)),
#  ('GarnishmentType1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 38)),
#  ('GenericAccountIdentification1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 39)),
#  ('GenericFinancialIdentification1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 40)),
#  ('GenericIdentification30',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 41)),
#  ('GenericOrganisationIdentification1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 42)),
#  ('GenericPersonIdentification1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 43)),
#  ('GroupHeader93', 'xs:complexType', ('xs:schema', 'xs:complexType', 44)),
#  ('IBAN2007Identifier', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 37)),
#  ('ISODate', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 38)),
#  ('ISODateTime', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 39)),
#  ('ISOTime', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 40)),
#  ('Instruction4Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 41)),
#  ('InstructionForCreditorAgent3',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 45)),
#  ('InstructionForNextAgent1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 46)),
#  ('LEIIdentifier', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 42)),
#  ('LocalInstrument2Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 47)),
#  ('MandateClassification1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 48)),
#  ('MandateClassification1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 43)),
#  ('MandateSetupReason1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 49)),
#  ('MandateTypeInformation2',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 50)),
#  ('Max10KBinary', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 44)),
#  ('Max10Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 45)),
#  ('Max128Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 46)),
#  ('Max140Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 47)),
#  ('Max15NumericText', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 48)),
#  ('Max16Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 49)),
#  ('Max2048Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 50)),
#  ('Max34Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 51)),
#  ('Max350Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 52)),
#  ('Max35Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 53)),
#  ('Max4Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 54)),
#  ('Max70Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 55)),
#  ('NameAndAddress16', 'xs:complexType', ('xs:schema', 'xs:complexType', 51)),
#  ('NamePrefix2Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 56)),
#  ('Number', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 57)),
#  ('OrganisationIdentification29',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 52)),
#  ('OrganisationIdentificationSchemeName1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 53)),
#  ('OtherContact1', 'xs:complexType', ('xs:schema', 'xs:complexType', 54)),
#  ('Party38Choice', 'xs:complexType', ('xs:schema', 'xs:complexType', 55)),
#  ('PartyIdentification135',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 56)),
#  ('PaymentIdentification13',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 57)),
#  ('PaymentTypeInformation28',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 58)),
#  ('PercentageRate', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 58)),
#  ('PersonIdentification13',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 59)),
#  ('PersonIdentificationSchemeName1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 60)),
#  ('PhoneNumber', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 59)),
#  ('PostalAddress24', 'xs:complexType', ('xs:schema', 'xs:complexType', 61)),
#  ('PreferredContactMethod1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 60)),
#  ('Priority2Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 61)),
#  ('Priority3Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 62)),
#  ('ProxyAccountIdentification1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 62)),
#  ('ProxyAccountType1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 63)),
#  ('Purpose2Choice', 'xs:complexType', ('xs:schema', 'xs:complexType', 64)),
#  ('ReferredDocumentInformation7',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 65)),
#  ('ReferredDocumentType3Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 66)),
#  ('ReferredDocumentType4',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 67)),
#  ('RegulatoryAuthority2',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 68)),
#  ('RegulatoryReporting3',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 69)),
#  ('RegulatoryReportingType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 63)),
#  ('RemittanceAmount2', 'xs:complexType', ('xs:schema', 'xs:complexType', 70)),
#  ('RemittanceAmount3', 'xs:complexType', ('xs:schema', 'xs:complexType', 71)),
#  ('RemittanceInformation16',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 72)),
#  ('RemittanceLocation7',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 73)),
#  ('RemittanceLocationData1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 74)),
#  ('RemittanceLocationMethod2Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 64)),
#  ('ServiceLevel8Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 75)),
#  ('SettlementDateTimeIndication1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 76)),
#  ('SettlementInstruction7',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 77)),
#  ('SettlementMethod1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 65)),
#  ('SettlementTimeRequest2',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 78)),
#  ('StructuredRegulatoryReporting3',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 79)),
#  ('StructuredRemittanceInformation16',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 80)),
#  ('SupplementaryData1', 'xs:complexType', ('xs:schema', 'xs:complexType', 81)),
#  ('SupplementaryDataEnvelope1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 82)),
#  ('TaxAmount2', 'xs:complexType', ('xs:schema', 'xs:complexType', 83)),
#  ('TaxAmountAndType1', 'xs:complexType', ('xs:schema', 'xs:complexType', 84)),
#  ('TaxAmountType1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 85)),
#  ('TaxAuthorisation1', 'xs:complexType', ('xs:schema', 'xs:complexType', 86)),
#  ('TaxInformation7', 'xs:complexType', ('xs:schema', 'xs:complexType', 87)),
#  ('TaxInformation8', 'xs:complexType', ('xs:schema', 'xs:complexType', 88)),
#  ('TaxParty1', 'xs:complexType', ('xs:schema', 'xs:complexType', 89)),
#  ('TaxParty2', 'xs:complexType', ('xs:schema', 'xs:complexType', 90)),
#  ('TaxPeriod2', 'xs:complexType', ('xs:schema', 'xs:complexType', 91)),
#  ('TaxRecord2', 'xs:complexType', ('xs:schema', 'xs:complexType', 92)),
#  ('TaxRecordDetails2', 'xs:complexType', ('xs:schema', 'xs:complexType', 93)),
#  ('TaxRecordPeriod1Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 66)),
#  ('TrueFalseIndicator', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 67)),
#  ('UUIDv4Identifier', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 68)),
#  ('xs:NOTATION', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 10)),
#  ('xs:QName', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 21)),
#  ('xs:anyURI', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 25)),
#  ('xs:base64Binary',
#   'xs:primitiveType',
#   ('xs:schema', 'xs:primitiveType', 11)),
#  ('xs:boolean', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 14)),
#  ('xs:byte', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 0)),
#  ('xs:date', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 12)),
#  ('xs:dateTime', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 3)),
#  ('xs:decimal', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 30)),
#  ('xs:double', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 29)),
#  ('xs:duration', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 17)),
#  ('xs:float', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 7)),
#  ('xs:gDay', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 23)),
#  ('xs:gMonth', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 16)),
#  ('xs:gMonthDay', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 5)),
#  ('xs:gYear', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 2)),
#  ('xs:gYearMonth', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 27)),
#  ('xs:hexBinary', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 4)),
#  ('xs:int', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 20)),
#  ('xs:integer', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 13)),
#  ('xs:negativeInteger',
#   'xs:primitiveType',
#   ('xs:schema', 'xs:primitiveType', 15)),
#  ('xs:nonNegativeInteger',
#   'xs:primitiveType',
#   ('xs:schema', 'xs:primitiveType', 28)),
#  ('xs:nonPositiveInteger',
#   'xs:primitiveType',
#   ('xs:schema', 'xs:primitiveType', 24)),
#  ('xs:positiveInteger',
#   'xs:primitiveType',
#   ('xs:schema', 'xs:primitiveType', 26)),
#  ('xs:short', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 22)),
#  ('xs:string', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 18)),
#  ('xs:time', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 8)),
#  ('xs:unsignedByte', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 1)),
#  ('xs:unsignedInt', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 6)),
#  ('xs:unsignedLong',
#   'xs:primitiveType',
#   ('xs:schema', 'xs:primitiveType', 19)),
#  ('xs:unsignedShort',
#   'xs:primitiveType',
#   ('xs:schema', 'xs:primitiveType', 9))}

# %%
cust_tp.data['xs:schema']['xs:element'][1]['xs:complexType'][ 'xs:sequence']['xs:element'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [32], line 1
# ----> 1 cust_tp.data['xs:schema']['xs:element'][1]['xs:complexType'][ 'xs:sequence']['xs:element'][0]
#
# KeyError: 1

# %%
# Resolve References
# Loop over the data, taking references where they exist and replacing them with their
# de-referenced lookup values
i=0
finished=False

cust_tp = tp.TreePath(cust_d)

while not finished:
    i = i + 1
    things_requiring_reference = build_path_index(cust_tp.data, index_tag="@ref")
    copy_tp = tp.TreePath(cust_tp.data)
    if len(things_requiring_reference)==0:
        finished=True
        break

    for k,v_list in things_requiring_reference.items():
#        print(k,v_list)
        for e,v in enumerate(v_list):
#            print("\t", e)
            ref_path = return_closest_path_match(named_things,k,v)
#            print("`",v,"`", ref_path)
            retain_content_d={ki:vi for ki,vi in access_dict(copy_tp.data, v).items() if ki != "@ref"}
            cust_tp.set(v, {**retain_content_d, **access_dict(copy_tp.data, ref_path[1])})
    print(i,len(things_requiring_reference))
#k,access_dict(cust_d, things_requiring_reference[k])

# %%
cust_tp.data
# Out:
# {'xs:schema': {'@xmlns': 'urn:iso:std:iso:20022:tech:xsd:pacs.008.001.09',
#   '@xmlns:xs': 'http://www.w3.org/2001/XMLSchema',
#   '@elementFormDefault': 'qualified',
#   '@targetNamespace': 'urn:iso:std:iso:20022:tech:xsd:pacs.008.001.09',
#   'xs:element': {'@name': 'Document', '@type': 'Document'},
#   'xs:complexType': [{'@name': 'AccountIdentification4Choice',
#     'xs:choice': {'xs:element': [{'@name': 'IBAN',
#        '@type': 'IBAN2007Identifier'},
#       {'@name': 'Othr', '@type': 'GenericAccountIdentification1'}]}},
#    {'@name': 'AccountSchemeName1Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalAccountIdentification1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'ActiveCurrencyAndAmount',
#     'xs:simpleContent': {'xs:extension': {'@base': 'ActiveCurrencyAndAmount_SimpleType',
#       'xs:attribute': {'@name': 'Ccy',
#        '@type': 'ActiveCurrencyCode',
#        '@use': 'required'}}}},
#    {'@name': 'ActiveOrHistoricCurrencyAndAmount',
#     'xs:simpleContent': {'xs:extension': {'@base': 'ActiveOrHistoricCurrencyAndAmount_SimpleType',
#       'xs:attribute': {'@name': 'Ccy',
#        '@type': 'ActiveOrHistoricCurrencyCode',
#        '@use': 'required'}}}},
#    {'@name': 'AddressType3Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd', '@type': 'AddressType2Code'},
#       {'@name': 'Prtry', '@type': 'GenericIdentification30'}]}},
#    {'@name': 'BranchAndFinancialInstitutionIdentification6',
#     'xs:sequence': {'xs:element': [{'@name': 'FinInstnId',
#        '@type': 'FinancialInstitutionIdentification18'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'BrnchId',
#        '@type': 'BranchData3'}]}},
#    {'@name': 'BranchData3',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Id',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'LEI',
#        '@type': 'LEIIdentifier'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Nm',
#        '@type': 'Max140Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PstlAdr',
#        '@type': 'PostalAddress24'}]}},
#    {'@name': 'CashAccount38',
#     'xs:sequence': {'xs:element': [{'@name': 'Id',
#        '@type': 'AccountIdentification4Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Tp',
#        '@type': 'CashAccountType2Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Ccy',
#        '@type': 'ActiveOrHistoricCurrencyCode'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Nm',
#        '@type': 'Max70Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Prxy',
#        '@type': 'ProxyAccountIdentification1'}]}},
#    {'@name': 'CashAccountType2Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalCashAccountType1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'CategoryPurpose1Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalCategoryPurpose1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'Charges7',
#     'xs:sequence': {'xs:element': [{'@name': 'Amt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@name': 'Agt',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'}]}},
#    {'@name': 'ClearingSystemIdentification2Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalClearingSystemIdentification1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'ClearingSystemIdentification3Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalCashClearingSystem1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'ClearingSystemMemberIdentification2',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'ClrSysId',
#        '@type': 'ClearingSystemIdentification2Choice'},
#       {'@name': 'MmbId', '@type': 'Max35Text'}]}},
#    {'@name': 'Contact4',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'NmPrfx',
#        '@type': 'NamePrefix2Code'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Nm',
#        '@type': 'Max140Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PhneNb',
#        '@type': 'PhoneNumber'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'MobNb',
#        '@type': 'PhoneNumber'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'FaxNb',
#        '@type': 'PhoneNumber'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'EmailAdr',
#        '@type': 'Max2048Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'EmailPurp',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'JobTitl',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Rspnsblty',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Dept',
#        '@type': 'Max70Text'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'Othr',
#        '@type': 'OtherContact1'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PrefrdMtd',
#        '@type': 'PreferredContactMethod1Code'}]}},
#    {'@name': 'CreditTransferMandateData1',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'MndtId',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Tp',
#        '@type': 'MandateTypeInformation2'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'DtOfSgntr',
#        '@type': 'ISODate'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'DtOfVrfctn',
#        '@type': 'ISODateTime'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'ElctrncSgntr',
#        '@type': 'Max10KBinary'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'FrstPmtDt',
#        '@type': 'ISODate'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'FnlPmtDt',
#        '@type': 'ISODate'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Frqcy',
#        '@type': 'Frequency36Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Rsn',
#        '@type': 'MandateSetupReason1Choice'}]}},
#    {'@name': 'CreditTransferTransaction43',
#     'xs:sequence': {'xs:element': [{'@name': 'PmtId',
#        '@type': 'PaymentIdentification13'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PmtTpInf',
#        '@type': 'PaymentTypeInformation28'},
#       {'@name': 'IntrBkSttlmAmt', '@type': 'ActiveCurrencyAndAmount'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'IntrBkSttlmDt',
#        '@type': 'ISODate'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'SttlmPrty',
#        '@type': 'Priority3Code'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'SttlmTmIndctn',
#        '@type': 'SettlementDateTimeIndication1'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'SttlmTmReq',
#        '@type': 'SettlementTimeRequest2'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'AccptncDtTm',
#        '@type': 'ISODateTime'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PoolgAdjstmntDt',
#        '@type': 'ISODate'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InstdAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'XchgRate',
#        '@type': 'BaseOneRate'},
#       {'@name': 'ChrgBr', '@type': 'ChargeBearerType1Code'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'ChrgsInf',
#        '@type': 'Charges7'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'MndtRltdInf',
#        '@type': 'CreditTransferMandateData1'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PrvsInstgAgt1',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PrvsInstgAgt1Acct',
#        '@type': 'CashAccount38'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PrvsInstgAgt2',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PrvsInstgAgt2Acct',
#        '@type': 'CashAccount38'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PrvsInstgAgt3',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PrvsInstgAgt3Acct',
#        '@type': 'CashAccount38'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InstgAgt',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InstdAgt',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'IntrmyAgt1',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'IntrmyAgt1Acct',
#        '@type': 'CashAccount38'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'IntrmyAgt2',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'IntrmyAgt2Acct',
#        '@type': 'CashAccount38'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'IntrmyAgt3',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'IntrmyAgt3Acct',
#        '@type': 'CashAccount38'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'UltmtDbtr',
#        '@type': 'PartyIdentification135'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InitgPty',
#        '@type': 'PartyIdentification135'},
#       {'@name': 'Dbtr', '@type': 'PartyIdentification135'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'DbtrAcct',
#        '@type': 'CashAccount38'},
#       {'@name': 'DbtrAgt',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'DbtrAgtAcct',
#        '@type': 'CashAccount38'},
#       {'@name': 'CdtrAgt',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CdtrAgtAcct',
#        '@type': 'CashAccount38'},
#       {'@name': 'Cdtr', '@type': 'PartyIdentification135'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CdtrAcct',
#        '@type': 'CashAccount38'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'UltmtCdtr',
#        '@type': 'PartyIdentification135'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'InstrForCdtrAgt',
#        '@type': 'InstructionForCreditorAgent3'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'InstrForNxtAgt',
#        '@type': 'InstructionForNextAgent1'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Purp',
#        '@type': 'Purpose2Choice'},
#       {'@maxOccurs': '10',
#        '@minOccurs': '0',
#        '@name': 'RgltryRptg',
#        '@type': 'RegulatoryReporting3'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Tax',
#        '@type': 'TaxInformation8'},
#       {'@maxOccurs': '10',
#        '@minOccurs': '0',
#        '@name': 'RltdRmtInf',
#        '@type': 'RemittanceLocation7'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RmtInf',
#        '@type': 'RemittanceInformation16'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'SplmtryData',
#        '@type': 'SupplementaryData1'}]}},
#    {'@name': 'CreditorReferenceInformation2',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Tp',
#        '@type': 'CreditorReferenceType2'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Ref',
#        '@type': 'Max35Text'}]}},
#    {'@name': 'CreditorReferenceType1Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd', '@type': 'DocumentType3Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'CreditorReferenceType2',
#     'xs:sequence': {'xs:element': [{'@name': 'CdOrPrtry',
#        '@type': 'CreditorReferenceType1Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Issr',
#        '@type': 'Max35Text'}]}},
#    {'@name': 'DateAndPlaceOfBirth1',
#     'xs:sequence': {'xs:element': [{'@name': 'BirthDt', '@type': 'ISODate'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PrvcOfBirth',
#        '@type': 'Max35Text'},
#       {'@name': 'CityOfBirth', '@type': 'Max35Text'},
#       {'@name': 'CtryOfBirth', '@type': 'CountryCode'}]}},
#    {'@name': 'DatePeriod2',
#     'xs:sequence': {'xs:element': [{'@name': 'FrDt', '@type': 'ISODate'},
#       {'@name': 'ToDt', '@type': 'ISODate'}]}},
#    {'@name': 'DiscountAmountAndType1',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Tp',
#        '@type': 'DiscountAmountType1Choice'},
#       {'@name': 'Amt', '@type': 'ActiveOrHistoricCurrencyAndAmount'}]}},
#    {'@name': 'DiscountAmountType1Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalDiscountAmountType1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'Document',
#     'xs:sequence': {'xs:element': {'@name': 'FIToFICstmrCdtTrf',
#       '@type': 'FIToFICustomerCreditTransferV09'}}},
#    {'@name': 'DocumentAdjustment1',
#     'xs:sequence': {'xs:element': [{'@name': 'Amt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CdtDbtInd',
#        '@type': 'CreditDebitCode'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Rsn',
#        '@type': 'Max4Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'AddtlInf',
#        '@type': 'Max140Text'}]}},
#    {'@name': 'DocumentLineIdentification1',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Tp',
#        '@type': 'DocumentLineType1'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Nb',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RltdDt',
#        '@type': 'ISODate'}]}},
#    {'@name': 'DocumentLineInformation1',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': 'unbounded',
#        '@minOccurs': '1',
#        '@name': 'Id',
#        '@type': 'DocumentLineIdentification1'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Desc',
#        '@type': 'Max2048Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Amt',
#        '@type': 'RemittanceAmount3'}]}},
#    {'@name': 'DocumentLineType1',
#     'xs:sequence': {'xs:element': [{'@name': 'CdOrPrtry',
#        '@type': 'DocumentLineType1Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Issr',
#        '@type': 'Max35Text'}]}},
#    {'@name': 'DocumentLineType1Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalDocumentLineType1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'FIToFICustomerCreditTransferV09',
#     'xs:sequence': {'xs:element': [{'@name': 'GrpHdr',
#        '@type': 'GroupHeader93'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '1',
#        '@name': 'CdtTrfTxInf',
#        '@type': 'CreditTransferTransaction43'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'SplmtryData',
#        '@type': 'SupplementaryData1'}]}},
#    {'@name': 'FinancialIdentificationSchemeName1Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalFinancialInstitutionIdentification1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'FinancialInstitutionIdentification18',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'BICFI',
#        '@type': 'BICFIDec2014Identifier'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'ClrSysMmbId',
#        '@type': 'ClearingSystemMemberIdentification2'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'LEI',
#        '@type': 'LEIIdentifier'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Nm',
#        '@type': 'Max140Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PstlAdr',
#        '@type': 'PostalAddress24'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Othr',
#        '@type': 'GenericFinancialIdentification1'}]}},
#    {'@name': 'Frequency36Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Tp', '@type': 'Frequency6Code'},
#       {'@name': 'Prd', '@type': 'FrequencyPeriod1'},
#       {'@name': 'PtInTm', '@type': 'FrequencyAndMoment1'}]}},
#    {'@name': 'FrequencyAndMoment1',
#     'xs:sequence': {'xs:element': [{'@name': 'Tp', '@type': 'Frequency6Code'},
#       {'@name': 'PtInTm', '@type': 'Exact2NumericText'}]}},
#    {'@name': 'FrequencyPeriod1',
#     'xs:sequence': {'xs:element': [{'@name': 'Tp', '@type': 'Frequency6Code'},
#       {'@name': 'CntPerPrd', '@type': 'DecimalNumber'}]}},
#    {'@name': 'Garnishment3',
#     'xs:sequence': {'xs:element': [{'@name': 'Tp',
#        '@type': 'GarnishmentType1'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Grnshee',
#        '@type': 'PartyIdentification135'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'GrnshmtAdmstr',
#        '@type': 'PartyIdentification135'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RefNb',
#        '@type': 'Max140Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Dt',
#        '@type': 'ISODate'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RmtdAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'FmlyMdclInsrncInd',
#        '@type': 'TrueFalseIndicator'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'MplyeeTermntnInd',
#        '@type': 'TrueFalseIndicator'}]}},
#    {'@name': 'GarnishmentType1',
#     'xs:sequence': {'xs:element': [{'@name': 'CdOrPrtry',
#        '@type': 'GarnishmentType1Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Issr',
#        '@type': 'Max35Text'}]}},
#    {'@name': 'GarnishmentType1Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalGarnishmentType1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'GenericAccountIdentification1',
#     'xs:sequence': {'xs:element': [{'@name': 'Id', '@type': 'Max34Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'SchmeNm',
#        '@type': 'AccountSchemeName1Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Issr',
#        '@type': 'Max35Text'}]}},
#    {'@name': 'GenericFinancialIdentification1',
#     'xs:sequence': {'xs:element': [{'@name': 'Id', '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'SchmeNm',
#        '@type': 'FinancialIdentificationSchemeName1Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Issr',
#        '@type': 'Max35Text'}]}},
#    {'@name': 'GenericIdentification30',
#     'xs:sequence': {'xs:element': [{'@name': 'Id',
#        '@type': 'Exact4AlphaNumericText'},
#       {'@name': 'Issr', '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'SchmeNm',
#        '@type': 'Max35Text'}]}},
#    {'@name': 'GenericOrganisationIdentification1',
#     'xs:sequence': {'xs:element': [{'@name': 'Id', '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'SchmeNm',
#        '@type': 'OrganisationIdentificationSchemeName1Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Issr',
#        '@type': 'Max35Text'}]}},
#    {'@name': 'GenericPersonIdentification1',
#     'xs:sequence': {'xs:element': [{'@name': 'Id', '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'SchmeNm',
#        '@type': 'PersonIdentificationSchemeName1Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Issr',
#        '@type': 'Max35Text'}]}},
#    {'@name': 'GroupHeader93',
#     'xs:sequence': {'xs:element': [{'@name': 'MsgId', '@type': 'Max35Text'},
#       {'@name': 'CreDtTm', '@type': 'ISODateTime'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'BtchBookg',
#        '@type': 'BatchBookingIndicator'},
#       {'@name': 'NbOfTxs', '@type': 'Max15NumericText'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CtrlSum',
#        '@type': 'DecimalNumber'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TtlIntrBkSttlmAmt',
#        '@type': 'ActiveCurrencyAndAmount'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'IntrBkSttlmDt',
#        '@type': 'ISODate'},
#       {'@name': 'SttlmInf', '@type': 'SettlementInstruction7'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PmtTpInf',
#        '@type': 'PaymentTypeInformation28'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InstgAgt',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InstdAgt',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'}]}},
#    {'@name': 'InstructionForCreditorAgent3',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Cd',
#        '@type': 'ExternalCreditorAgentInstruction1Code'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InstrInf',
#        '@type': 'Max140Text'}]}},
#    {'@name': 'InstructionForNextAgent1',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Cd',
#        '@type': 'Instruction4Code'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InstrInf',
#        '@type': 'Max140Text'}]}},
#    {'@name': 'LocalInstrument2Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalLocalInstrument1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'MandateClassification1Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'MandateClassification1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'MandateSetupReason1Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalMandateSetupReason1Code'},
#       {'@name': 'Prtry', '@type': 'Max70Text'}]}},
#    {'@name': 'MandateTypeInformation2',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'SvcLvl',
#        '@type': 'ServiceLevel8Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'LclInstrm',
#        '@type': 'LocalInstrument2Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CtgyPurp',
#        '@type': 'CategoryPurpose1Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Clssfctn',
#        '@type': 'MandateClassification1Choice'}]}},
#    {'@name': 'NameAndAddress16',
#     'xs:sequence': {'xs:element': [{'@name': 'Nm', '@type': 'Max140Text'},
#       {'@name': 'Adr', '@type': 'PostalAddress24'}]}},
#    {'@name': 'OrganisationIdentification29',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'AnyBIC',
#        '@type': 'AnyBICDec2014Identifier'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'LEI',
#        '@type': 'LEIIdentifier'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'Othr',
#        '@type': 'GenericOrganisationIdentification1'}]}},
#    {'@name': 'OrganisationIdentificationSchemeName1Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalOrganisationIdentification1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'OtherContact1',
#     'xs:sequence': {'xs:element': [{'@name': 'ChanlTp', '@type': 'Max4Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Id',
#        '@type': 'Max128Text'}]}},
#    {'@name': 'Party38Choice',
#     'xs:choice': {'xs:element': [{'@name': 'OrgId',
#        '@type': 'OrganisationIdentification29'},
#       {'@name': 'PrvtId', '@type': 'PersonIdentification13'}]}},
#    {'@name': 'PartyIdentification135',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Nm',
#        '@type': 'Max140Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PstlAdr',
#        '@type': 'PostalAddress24'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Id',
#        '@type': 'Party38Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CtryOfRes',
#        '@type': 'CountryCode'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CtctDtls',
#        '@type': 'Contact4'}]}},
#    {'@name': 'PaymentIdentification13',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InstrId',
#        '@type': 'Max35Text'},
#       {'@name': 'EndToEndId', '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TxId',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'UETR',
#        '@type': 'UUIDv4Identifier'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'ClrSysRef',
#        '@type': 'Max35Text'}]}},
#    {'@name': 'PaymentTypeInformation28',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InstrPrty',
#        '@type': 'Priority2Code'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'ClrChanl',
#        '@type': 'ClearingChannel2Code'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'SvcLvl',
#        '@type': 'ServiceLevel8Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'LclInstrm',
#        '@type': 'LocalInstrument2Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CtgyPurp',
#        '@type': 'CategoryPurpose1Choice'}]}},
#    {'@name': 'PersonIdentification13',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'DtAndPlcOfBirth',
#        '@type': 'DateAndPlaceOfBirth1'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'Othr',
#        '@type': 'GenericPersonIdentification1'}]}},
#    {'@name': 'PersonIdentificationSchemeName1Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalPersonIdentification1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'PostalAddress24',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'AdrTp',
#        '@type': 'AddressType3Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Dept',
#        '@type': 'Max70Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'SubDept',
#        '@type': 'Max70Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'StrtNm',
#        '@type': 'Max70Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'BldgNb',
#        '@type': 'Max16Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'BldgNm',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Flr',
#        '@type': 'Max70Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PstBx',
#        '@type': 'Max16Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Room',
#        '@type': 'Max70Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PstCd',
#        '@type': 'Max16Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TwnNm',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TwnLctnNm',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'DstrctNm',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CtrySubDvsn',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Ctry',
#        '@type': 'CountryCode'},
#       {'@maxOccurs': '7',
#        '@minOccurs': '0',
#        '@name': 'AdrLine',
#        '@type': 'Max70Text'}]}},
#    {'@name': 'ProxyAccountIdentification1',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Tp',
#        '@type': 'ProxyAccountType1Choice'},
#       {'@name': 'Id', '@type': 'Max2048Text'}]}},
#    {'@name': 'ProxyAccountType1Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalProxyAccountType1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'Purpose2Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalPurpose1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'ReferredDocumentInformation7',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Tp',
#        '@type': 'ReferredDocumentType4'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Nb',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RltdDt',
#        '@type': 'ISODate'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'LineDtls',
#        '@type': 'DocumentLineInformation1'}]}},
#    {'@name': 'ReferredDocumentType3Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd', '@type': 'DocumentType6Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'ReferredDocumentType4',
#     'xs:sequence': {'xs:element': [{'@name': 'CdOrPrtry',
#        '@type': 'ReferredDocumentType3Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Issr',
#        '@type': 'Max35Text'}]}},
#    {'@name': 'RegulatoryAuthority2',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Nm',
#        '@type': 'Max140Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Ctry',
#        '@type': 'CountryCode'}]}},
#    {'@name': 'RegulatoryReporting3',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'DbtCdtRptgInd',
#        '@type': 'RegulatoryReportingType1Code'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Authrty',
#        '@type': 'RegulatoryAuthority2'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'Dtls',
#        '@type': 'StructuredRegulatoryReporting3'}]}},
#    {'@name': 'RemittanceAmount2',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'DuePyblAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'DscntApldAmt',
#        '@type': 'DiscountAmountAndType1'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CdtNoteAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'TaxAmt',
#        '@type': 'TaxAmountAndType1'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'AdjstmntAmtAndRsn',
#        '@type': 'DocumentAdjustment1'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RmtdAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'}]}},
#    {'@name': 'RemittanceAmount3',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'DuePyblAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'DscntApldAmt',
#        '@type': 'DiscountAmountAndType1'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CdtNoteAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'TaxAmt',
#        '@type': 'TaxAmountAndType1'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'AdjstmntAmtAndRsn',
#        '@type': 'DocumentAdjustment1'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RmtdAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'}]}},
#    {'@name': 'RemittanceInformation16',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'Ustrd',
#        '@type': 'Max140Text'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'Strd',
#        '@type': 'StructuredRemittanceInformation16'}]}},
#    {'@name': 'RemittanceLocation7',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RmtId',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'RmtLctnDtls',
#        '@type': 'RemittanceLocationData1'}]}},
#    {'@name': 'RemittanceLocationData1',
#     'xs:sequence': {'xs:element': [{'@name': 'Mtd',
#        '@type': 'RemittanceLocationMethod2Code'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'ElctrncAdr',
#        '@type': 'Max2048Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PstlAdr',
#        '@type': 'NameAndAddress16'}]}},
#    {'@name': 'ServiceLevel8Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalServiceLevel1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'SettlementDateTimeIndication1',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'DbtDtTm',
#        '@type': 'ISODateTime'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CdtDtTm',
#        '@type': 'ISODateTime'}]}},
#    {'@name': 'SettlementInstruction7',
#     'xs:sequence': {'xs:element': [{'@name': 'SttlmMtd',
#        '@type': 'SettlementMethod1Code'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'SttlmAcct',
#        '@type': 'CashAccount38'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'ClrSys',
#        '@type': 'ClearingSystemIdentification3Choice'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InstgRmbrsmntAgt',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InstgRmbrsmntAgtAcct',
#        '@type': 'CashAccount38'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InstdRmbrsmntAgt',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'InstdRmbrsmntAgtAcct',
#        '@type': 'CashAccount38'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'ThrdRmbrsmntAgt',
#        '@type': 'BranchAndFinancialInstitutionIdentification6'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'ThrdRmbrsmntAgtAcct',
#        '@type': 'CashAccount38'}]}},
#    {'@name': 'SettlementTimeRequest2',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CLSTm',
#        '@type': 'ISOTime'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TillTm',
#        '@type': 'ISOTime'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'FrTm',
#        '@type': 'ISOTime'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RjctTm',
#        '@type': 'ISOTime'}]}},
#    {'@name': 'StructuredRegulatoryReporting3',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Tp',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Dt',
#        '@type': 'ISODate'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Ctry',
#        '@type': 'CountryCode'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Cd',
#        '@type': 'Max10Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Amt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'Inf',
#        '@type': 'Max35Text'}]}},
#    {'@name': 'StructuredRemittanceInformation16',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'RfrdDocInf',
#        '@type': 'ReferredDocumentInformation7'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RfrdDocAmt',
#        '@type': 'RemittanceAmount2'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CdtrRefInf',
#        '@type': 'CreditorReferenceInformation2'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Invcr',
#        '@type': 'PartyIdentification135'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Invcee',
#        '@type': 'PartyIdentification135'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TaxRmt',
#        '@type': 'TaxInformation7'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'GrnshmtRmt',
#        '@type': 'Garnishment3'},
#       {'@maxOccurs': '3',
#        '@minOccurs': '0',
#        '@name': 'AddtlRmtInf',
#        '@type': 'Max140Text'}]}},
#    {'@name': 'SupplementaryData1',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'PlcAndNm',
#        '@type': 'Max350Text'},
#       {'@name': 'Envlp', '@type': 'SupplementaryDataEnvelope1'}]}},
#    {'@name': 'SupplementaryDataEnvelope1',
#     'xs:sequence': {'xs:any': {'@namespace': '##any',
#       '@processContents': 'lax'}}},
#    {'@name': 'TaxAmount2',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Rate',
#        '@type': 'PercentageRate'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TaxblBaseAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TtlAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'Dtls',
#        '@type': 'TaxRecordDetails2'}]}},
#    {'@name': 'TaxAmountAndType1',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Tp',
#        '@type': 'TaxAmountType1Choice'},
#       {'@name': 'Amt', '@type': 'ActiveOrHistoricCurrencyAndAmount'}]}},
#    {'@name': 'TaxAmountType1Choice',
#     'xs:choice': {'xs:element': [{'@name': 'Cd',
#        '@type': 'ExternalTaxAmountType1Code'},
#       {'@name': 'Prtry', '@type': 'Max35Text'}]}},
#    {'@name': 'TaxAuthorisation1',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Titl',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Nm',
#        '@type': 'Max140Text'}]}},
#    {'@name': 'TaxInformation7',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Cdtr',
#        '@type': 'TaxParty1'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Dbtr',
#        '@type': 'TaxParty2'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'UltmtDbtr',
#        '@type': 'TaxParty2'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'AdmstnZone',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RefNb',
#        '@type': 'Max140Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Mtd',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TtlTaxblBaseAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TtlTaxAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Dt',
#        '@type': 'ISODate'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'SeqNb',
#        '@type': 'Number'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'Rcrd',
#        '@type': 'TaxRecord2'}]}},
#    {'@name': 'TaxInformation8',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Cdtr',
#        '@type': 'TaxParty1'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Dbtr',
#        '@type': 'TaxParty2'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'AdmstnZone',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RefNb',
#        '@type': 'Max140Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Mtd',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TtlTaxblBaseAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TtlTaxAmt',
#        '@type': 'ActiveOrHistoricCurrencyAndAmount'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Dt',
#        '@type': 'ISODate'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'SeqNb',
#        '@type': 'Number'},
#       {'@maxOccurs': 'unbounded',
#        '@minOccurs': '0',
#        '@name': 'Rcrd',
#        '@type': 'TaxRecord2'}]}},
#    {'@name': 'TaxParty1',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TaxId',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RegnId',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TaxTp',
#        '@type': 'Max35Text'}]}},
#    {'@name': 'TaxParty2',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TaxId',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'RegnId',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TaxTp',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Authstn',
#        '@type': 'TaxAuthorisation1'}]}},
#    {'@name': 'TaxPeriod2',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Yr',
#        '@type': 'ISODate'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Tp',
#        '@type': 'TaxRecordPeriod1Code'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'FrToDt',
#        '@type': 'DatePeriod2'}]}},
#    {'@name': 'TaxRecord2',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Tp',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Ctgy',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CtgyDtls',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'DbtrSts',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'CertId',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'FrmsCd',
#        '@type': 'Max35Text'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Prd',
#        '@type': 'TaxPeriod2'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'TaxAmt',
#        '@type': 'TaxAmount2'},
#       {'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'AddtlInf',
#        '@type': 'Max140Text'}]}},
#    {'@name': 'TaxRecordDetails2',
#     'xs:sequence': {'xs:element': [{'@maxOccurs': '1',
#        '@minOccurs': '0',
#        '@name': 'Prd',
#        '@type': 'TaxPeriod2'},
#       {'@name': 'Amt', '@type': 'ActiveOrHistoricCurrencyAndAmount'}]}}],
#   'xs:simpleType': [{'@name': 'ActiveCurrencyAndAmount_SimpleType',
#     'xs:restriction': {'@base': 'xs:decimal',
#      'xs:fractionDigits': {'@value': '5'},
#      'xs:totalDigits': {'@value': '18'},
#      'xs:minInclusive': {'@value': '0'}}},
#    {'@name': 'ActiveCurrencyCode',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:pattern': {'@value': '[A-Z]{3,3}'}}},
#    {'@name': 'ActiveOrHistoricCurrencyAndAmount_SimpleType',
#     'xs:restriction': {'@base': 'xs:decimal',
#      'xs:fractionDigits': {'@value': '5'},
#      'xs:totalDigits': {'@value': '18'},
#      'xs:minInclusive': {'@value': '0'}}},
#    {'@name': 'ActiveOrHistoricCurrencyCode',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:pattern': {'@value': '[A-Z]{3,3}'}}},
#    {'@name': 'AddressType2Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'ADDR'},
#       {'@value': 'PBOX'},
#       {'@value': 'HOME'},
#       {'@value': 'BIZZ'},
#       {'@value': 'MLTO'},
#       {'@value': 'DLVY'}]}},
#    {'@name': 'AnyBICDec2014Identifier',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:pattern': {'@value': '[A-Z0-9]{4,4}[A-Z]{2,2}[A-Z0-9]{2,2}([A-Z0-9]{3,3}){0,1}'}}},
#    {'@name': 'BICFIDec2014Identifier',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:pattern': {'@value': '[A-Z0-9]{4,4}[A-Z]{2,2}[A-Z0-9]{2,2}([A-Z0-9]{3,3}){0,1}'}}},
#    {'@name': 'BaseOneRate',
#     'xs:restriction': {'@base': 'xs:decimal',
#      'xs:fractionDigits': {'@value': '10'},
#      'xs:totalDigits': {'@value': '11'}}},
#    {'@name': 'BatchBookingIndicator',
#     'xs:restriction': {'@base': 'xs:boolean'}},
#    {'@name': 'ChargeBearerType1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'DEBT'},
#       {'@value': 'CRED'},
#       {'@value': 'SHAR'},
#       {'@value': 'SLEV'}]}},
#    {'@name': 'ClearingChannel2Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'RTGS'},
#       {'@value': 'RTNS'},
#       {'@value': 'MPNS'},
#       {'@value': 'BOOK'}]}},
#    {'@name': 'CountryCode',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:pattern': {'@value': '[A-Z]{2,2}'}}},
#    {'@name': 'CreditDebitCode',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'CRDT'}, {'@value': 'DBIT'}]}},
#    {'@name': 'DecimalNumber',
#     'xs:restriction': {'@base': 'xs:decimal',
#      'xs:fractionDigits': {'@value': '17'},
#      'xs:totalDigits': {'@value': '18'}}},
#    {'@name': 'DocumentType3Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'RADM'},
#       {'@value': 'RPIN'},
#       {'@value': 'FXDR'},
#       {'@value': 'DISP'},
#       {'@value': 'PUOR'},
#       {'@value': 'SCOR'}]}},
#    {'@name': 'DocumentType6Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'MSIN'},
#       {'@value': 'CNFA'},
#       {'@value': 'DNFA'},
#       {'@value': 'CINV'},
#       {'@value': 'CREN'},
#       {'@value': 'DEBN'},
#       {'@value': 'HIRI'},
#       {'@value': 'SBIN'},
#       {'@value': 'CMCN'},
#       {'@value': 'SOAC'},
#       {'@value': 'DISP'},
#       {'@value': 'BOLD'},
#       {'@value': 'VCHR'},
#       {'@value': 'AROI'},
#       {'@value': 'TSUT'},
#       {'@value': 'PUOR'}]}},
#    {'@name': 'Exact2NumericText',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:pattern': {'@value': '[0-9]{2}'}}},
#    {'@name': 'Exact4AlphaNumericText',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:pattern': {'@value': '[a-zA-Z0-9]{4}'}}},
#    {'@name': 'ExternalAccountIdentification1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalCashAccountType1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalCashClearingSystem1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '3'}}},
#    {'@name': 'ExternalCategoryPurpose1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalClearingSystemIdentification1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '5'}}},
#    {'@name': 'ExternalCreditorAgentInstruction1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalDiscountAmountType1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalDocumentLineType1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalFinancialInstitutionIdentification1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalGarnishmentType1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalLocalInstrument1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '35'}}},
#    {'@name': 'ExternalMandateSetupReason1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalOrganisationIdentification1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalPersonIdentification1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalProxyAccountType1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalPurpose1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalServiceLevel1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'ExternalTaxAmountType1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'Frequency6Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'YEAR'},
#       {'@value': 'MNTH'},
#       {'@value': 'QURT'},
#       {'@value': 'MIAN'},
#       {'@value': 'WEEK'},
#       {'@value': 'DAIL'},
#       {'@value': 'ADHO'},
#       {'@value': 'INDA'},
#       {'@value': 'FRTN'}]}},
#    {'@name': 'IBAN2007Identifier',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:pattern': {'@value': '[A-Z]{2,2}[0-9]{2,2}[a-zA-Z0-9]{1,30}'}}},
#    {'@name': 'ISODate', 'xs:restriction': {'@base': 'xs:date'}},
#    {'@name': 'ISODateTime', 'xs:restriction': {'@base': 'xs:dateTime'}},
#    {'@name': 'ISOTime', 'xs:restriction': {'@base': 'xs:time'}},
#    {'@name': 'Instruction4Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'PHOA'}, {'@value': 'TELA'}]}},
#    {'@name': 'LEIIdentifier',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:pattern': {'@value': '[A-Z0-9]{18,18}[0-9]{2,2}'}}},
#    {'@name': 'MandateClassification1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'FIXE'},
#       {'@value': 'USGB'},
#       {'@value': 'VARI'}]}},
#    {'@name': 'Max10KBinary',
#     'xs:restriction': {'@base': 'xs:base64Binary',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '10240'}}},
#    {'@name': 'Max10Text',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '10'}}},
#    {'@name': 'Max128Text',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '128'}}},
#    {'@name': 'Max140Text',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '140'}}},
#    {'@name': 'Max15NumericText',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:pattern': {'@value': '[0-9]{1,15}'}}},
#    {'@name': 'Max16Text',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '16'}}},
#    {'@name': 'Max2048Text',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '2048'}}},
#    {'@name': 'Max34Text',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '34'}}},
#    {'@name': 'Max350Text',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '350'}}},
#    {'@name': 'Max35Text',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '35'}}},
#    {'@name': 'Max4Text',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '4'}}},
#    {'@name': 'Max70Text',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:minLength': {'@value': '1'},
#      'xs:maxLength': {'@value': '70'}}},
#    {'@name': 'NamePrefix2Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'DOCT'},
#       {'@value': 'MADM'},
#       {'@value': 'MISS'},
#       {'@value': 'MIST'},
#       {'@value': 'MIKS'}]}},
#    {'@name': 'Number',
#     'xs:restriction': {'@base': 'xs:decimal',
#      'xs:fractionDigits': {'@value': '0'},
#      'xs:totalDigits': {'@value': '18'}}},
#    {'@name': 'PercentageRate',
#     'xs:restriction': {'@base': 'xs:decimal',
#      'xs:fractionDigits': {'@value': '10'},
#      'xs:totalDigits': {'@value': '11'}}},
#    {'@name': 'PhoneNumber',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:pattern': {'@value': '\\+[0-9]{1,3}-[0-9()+\\-]{1,30}'}}},
#    {'@name': 'PreferredContactMethod1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'LETT'},
#       {'@value': 'MAIL'},
#       {'@value': 'PHON'},
#       {'@value': 'FAXX'},
#       {'@value': 'CELL'}]}},
#    {'@name': 'Priority2Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'HIGH'}, {'@value': 'NORM'}]}},
#    {'@name': 'Priority3Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'URGT'},
#       {'@value': 'HIGH'},
#       {'@value': 'NORM'}]}},
#    {'@name': 'RegulatoryReportingType1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'CRED'},
#       {'@value': 'DEBT'},
#       {'@value': 'BOTH'}]}},
#    {'@name': 'RemittanceLocationMethod2Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'FAXI'},
#       {'@value': 'EDIC'},
#       {'@value': 'URID'},
#       {'@value': 'EMAL'},
#       {'@value': 'POST'},
#       {'@value': 'SMSM'}]}},
#    {'@name': 'SettlementMethod1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'INDA'},
#       {'@value': 'INGA'},
#       {'@value': 'COVE'},
#       {'@value': 'CLRG'}]}},
#    {'@name': 'TaxRecordPeriod1Code',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:enumeration': [{'@value': 'MM01'},
#       {'@value': 'MM02'},
#       {'@value': 'MM03'},
#       {'@value': 'MM04'},
#       {'@value': 'MM05'},
#       {'@value': 'MM06'},
#       {'@value': 'MM07'},
#       {'@value': 'MM08'},
#       {'@value': 'MM09'},
#       {'@value': 'MM10'},
#       {'@value': 'MM11'},
#       {'@value': 'MM12'},
#       {'@value': 'QTR1'},
#       {'@value': 'QTR2'},
#       {'@value': 'QTR3'},
#       {'@value': 'QTR4'},
#       {'@value': 'HLF1'},
#       {'@value': 'HLF2'}]}},
#    {'@name': 'TrueFalseIndicator', 'xs:restriction': {'@base': 'xs:boolean'}},
#    {'@name': 'UUIDv4Identifier',
#     'xs:restriction': {'@base': 'xs:string',
#      'xs:pattern': {'@value': '[a-f0-9]{8}-[a-f0-9]{4}-4[a-f0-9]{3}-[89ab][a-f0-9]{3}-[a-f0-9]{12}'}}}],
#   'xs:primitiveType': [{'@name': 'xs:byte'},
#    {'@name': 'xs:unsignedByte'},
#    {'@name': 'xs:gYear'},
#    {'@name': 'xs:dateTime'},
#    {'@name': 'xs:hexBinary'},
#    {'@name': 'xs:gMonthDay'},
#    {'@name': 'xs:unsignedInt'},
#    {'@name': 'xs:float'},
#    {'@name': 'xs:time'},
#    {'@name': 'xs:unsignedShort'},
#    {'@name': 'xs:NOTATION'},
#    {'@name': 'xs:base64Binary'},
#    {'@name': 'xs:date'},
#    {'@name': 'xs:integer'},
#    {'@name': 'xs:boolean'},
#    {'@name': 'xs:negativeInteger'},
#    {'@name': 'xs:gMonth'},
#    {'@name': 'xs:duration'},
#    {'@name': 'xs:string'},
#    {'@name': 'xs:unsignedLong'},
#    {'@name': 'xs:int'},
#    {'@name': 'xs:QName'},
#    {'@name': 'xs:short'},
#    {'@name': 'xs:gDay'},
#    {'@name': 'xs:nonPositiveInteger'},
#    {'@name': 'xs:anyURI'},
#    {'@name': 'xs:positiveInteger'},
#    {'@name': 'xs:gYearMonth'},
#    {'@name': 'xs:nonNegativeInteger'},
#    {'@name': 'xs:double'},
#    {'@name': 'xs:decimal'}]}}

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 assert False
#
# AssertionError:

# %%
    referred_things=gen_labelled_path_dict(cust_tp.data, index_tag="@ref")

    for n, paths in referred_things.items():
        for p in paths:
            #print(p)
            name = n
            obj=access_dict(cust_tp.data, p[1])
            org=access_dict(cust_d, p[1])
            print(n, p[0], p[1], obj, org)

# %%
cust_tp.data

# %%
referred_things

# %%
assert False

# %%
access_dict(cust_d, named_things.get('test_by_reference')[0][1][:-2])

# %%
cust_d

# %%
access_dict(cust_d, named_things.get( 'Document')[0])

named_things.get( 'Document')

# %%
named_things.get('root')[0]
#access_dict(cust_d, named_things.get( 'root')[0][:-1])

# %%
build_path_index(cust_d, index_tag="@ref")

# %%
for k,v_list in things_requiring_reference.items():
    print(k,v_list)
    for e,v in enumerate(v_list):
        print(e)
        ref_path = return_closest_path_match(named_things,k,v)
        #print(v, ref_path)
        cust_tp.set(v, access_dict(cust_d, ref_path))
    print()

# %%
cust_tp.data

# %%
t_i = build_path_index(cust_d,"@name")

{k:[access_dict(cust_d, q) for q in v] for k,v in t_i.items()}

test_path = ['xs:schema', 'xs:complexType', 1,'xs:element', 1, 1, 1, 2, 'xs:complexType', 'xs:complexContent']

return_closest_path_match(t_i, "element5", test_path)

# %%
TreePath._shortest_common_path([t_i.get("element5")[0], test_path])

# %%
named_things

# %%
t_i['element5']

# %%
# 2) Classify the things:
c_dict={}
df_records=[]
for path in named_things:
    thing_name = access_dict(cust_d, path + ["@name"])
    # Does this thing have a type?
    if "@type" in access_dict(cust_d, path).keys():
        thing_type = access_dict(cust_d, path + ["@type"])
    else:
        thing_type = None
    # Does this thing reference a type via an extension or restriction "base"?
    if any([n in ('xs:restriction', 'xs:extension') for n in access_dict(cust_d, path).keys()]):
        base_context = [n for n in access_dict(cust_d, path).keys() if n in ('xs:restriction', 'xs:extension') ][0]
        thing_base = access_dict(cust_d, path+[base_context, '@base'])
    elif any([n in ('xs:simpleContent', 'xs:complexContent') for n in access_dict(cust_d, path).keys()]):
        content_type=[n for n in access_dict(cust_d, path).keys() if n in ('xs:simpleContent', 'xs:complexContent')][0]
        base_context = [n for n in access_dict(cust_d, path+[content_type]).keys() if n in ('xs:restriction', 'xs:extension') ][0]
        thing_base = access_dict(cust_d, path+[content_type, base_context, '@base'])
    else:
        content_type =None
        base_context = None
        thing_base = None
    # Does this thing contain one of the container types that might point to multiple elements?
    if any([n in ('xs:all', 'xs:group', 'xs:choice','xs:sequence') for n in access_dict(cust_d, path).keys()]):
        thing_contains_collection = True
    else:
        thing_contains_collection = False
        
    # What is this thing's parent object class? 
    if isnumeric(path[-1]):
        thing_expression_type = path[-2]
    else:
        thing_expression_type = path[-1]
    # Build a counter of parent expression types 
    if thing_expression_type in c_dict.keys():
        c_dict[thing_expression_type]=c_dict[thing_expression_type]+1
    else:
        c_dict[thing_expression_type]=1
    
    # Print some things
    df_records.append((thing_name, thing_type, thing_expression_type, thing_base, base_context, thing_contains_collection, content_type))
    
xsd_df = pd.DataFrame(df_records, columns=["Name", "Type", "expression_type", "base", "base_context", "has_collection", "content_type"])
xsd_df

# %%
xsd_df[xsd_df[["expression_type", "content_type"]].isnull().apply(lambda x : not any([y for y in x]), axis=1)]

# %%
c_dict

# %%
# 2) Classify the things:
typed_collection = {}
for path in named_things:
    thing_name = access_dict(cust_d, path + ["@name"])
    if isnumeric(path[-1]):
        thing_type = path[-2]
    else:
        thing_type = path[-1]
    if thing_type in typed_collection.keys():
        typed_collection[thing_type].append(path)
    else:
        typed_collection[thing_type]=[path]
    print (path,  thing_name, thing_type)

# %%
path=['xs:schema', 'xs:complexType', 2, 'xs:complexContent', 'xs:extension', 'xs:attribute']
access_dict(cust_d, path)

# %%
[access_dict(cust_d, path) for path in chain(*typed_collection.values())]

# %%
# Of the named things extracted, what are their parent types?
{k:len(v) for k,v in typed_collection.items()}

# %%
# Of the things extracted, which are terminal items?
terminals = {s for s in primitives_set}
log=[]
for k,v in typed_collection.items():
    print(k)
    for path in v:
        node = access_dict(cust_d, path)
        if "@type" in node.keys():
            if (node['@type'] in terminals):
                log.append(k)
                terminals.add(node["@name"])
            else:
                print(k, "no terminal")
        if "xs:restriction" in node.keys():
            if node["xs:restriction"]["@base"] in terminals:
                
                terminals.add(node["@name"])
                log.append(k)
            else:
                print(k, "no terminal")
        
log

# %%
for k,v in typed_collection.items():
    
    if k == "xs:complexType":
        for path in v:
            node = access_dict(cust_d, path)
            if "xs:sequence" in node.keys():
                print(node["@name"])
                if 'xs:element' in node['xs:sequence'].keys():
                    print (len(node['xs:sequence']['xs:element']))
                    print (type(node['xs:sequence']['xs:element']))
                    if isinstance(node['xs:sequence']['xs:element'], list):
                        for h,i in node['xs:sequence'].items():
                            for si in i:
#                                print(si)
                                print("\t", str(si["@name"]), "<" + si["@type"] + ">")
                    else:
                        si = node['xs:sequence']['xs:element']
#                        print(si)
                        print("\t", str(si["@name"]), "<" + si["@type"] + ">")

            print()
            print()

# %%
class TypeDefinition(object):
    def __init__(self, type_dict):
        if "@name" in type_dict.keys():
            self.name = type_dict['@name']
        else:
            assert False
        if "@id" in type_dict.keys():
            self.id = type_dict['@id']
        self.children=[]
            
    def parse_restriction(self, type_dict):
        if "xs:restriction" in type_dict.keys():
            if "@base" in type_dict['xs:restriction'].keys():
                self.children.append ( type_dict['xs:restriction']['@base'])
                
    def parse_extension(self, type_dict):
        if "xs:extension" in type_dict.keys():
            if "@base" in type_dict['xs:extension'].keys():
                self.children.append ( type_dict['xs:extension']['@base'])
                
    def parse_all(self, type_dict):
        if "xs:all" in type_dict.keys():
            for e in type_dict['xs:all']:
                self.parse_element(e)
        
    def parse_group(self, type_dict):
        
    def parse_sequence(self, type_dict):
        
    def parse_choice(self, type_dict):
        
    def parse_attribute(self, type_dict):
        
    def parse_attribute_group(self, type_dict):
        
    def parse_simple_content(self, type_dict):

    def parse_complex_content(self, type_dict):

    def parse_union(self, type_dict):
        if "xs:union" in type_dict.keys():
            if "@memberTypes" in type_dict['xs:union'].keys():
                self.children.append ( type_dict['xs:list']["@memberTypes"] )
                
    def parse_list(self, type_dict):
        if "xs:list" in type_dict.keys():
            if "@itemType" in type_dict['xs:list'].keys():
                self.children.append ( type_dict['xs:list']["@itemType"] )
                
    def parse_element(self, type_dict):
        
        
class SimpleType(TypeDefinition):
    
    def __init__(self, type_dict):
        
        super().__init__(type_dict)

            
    def __repr__(self):
        return str(self.name) + ":<" + str(self.base) + ">(primitive:" + str(self.primitive) + ")"
    
class ComplexType(TypeDefinition):
    
    def __init__(self, type_dict):
        
        super().__init__(type_dict)
            
            
    def __repr__(self):
        return str(self.name) + ":<" + str(None) + ">"

# %%
[(p, access_dict(cust_d, p)) for p in typed_collection['xs:element']]

# %%
[(p, access_dict(cust_d, p)) for p in typed_collection['xs:element']]

# %%
k=['xs:schema', 'xs:complexType', 20]
reduce(operator.getitem, k, cust_d)

# %%
k=['xs:schema', 'xs:complexType', 88]
reduce(operator.getitem, k, cust_d)

# %%
Counter({tuple(k):reduce(operator.getitem, k, cust_d)  for k in leaves if k[-1]=="@name"}.values())

# %%
cust_d

# %%
raw_names_d, raw_bases_d, raw_types_d, raw_primitives_d, raw_primitives_labels_d, ref_keys, specification_d = xsdparse.parse_xsd(customer_xsd)

# %%
reduce(operator.getitem, ['xs:schema', 'xs:complexType', 2], cust_d)

# %%
xsdparse.build_(specification_d.get("customerinfo")[0],specification_d)

# %%
ref_keys

# %%
"""
xsdparse
===========

A utility for parsing an xsd and producing a model specification.

"""
import xmltodict
import zipfile
from collections import Counter
import os, sys
sys.path.append(os.path.abspath("../treepath"))
import treepath.treepath as tp

import pandas as pd
import networkx as nx


def key_scan_obj(obj, search=None, path=None, results=None):
    if results is None:
        results = []
    if search is None:
        search = None
    if path is None:
        path = []
    if isinstance(obj, dict):
        for k,v in obj.items():
            if (k==search or v==search):
                results.append({"path" : path+[k], "value" : v})
            elif isinstance(v, (dict, list)):
                results.extend(key_scan_obj(v, search=search, path=path + [k]))
    elif isinstance(obj, list):
        for e,v in enumerate(obj):
            if v==search:
                results.append({"path" : path+[e], "value" : v})
            elif isinstance(v, (dict, list)):
                results.extend(key_scan_obj(v, search=search, path = path + [e]))
    else:
        if v==search or search is None:
            results.append({"path" : path, "value" : v})
    return results

prims=[ {'@name': 'xs:duration'},
        {'@name': 'xs:dateTime'},
        {'@name': 'xs:time'},
        {'@name': 'xs:date'},
        {'@name': 'xs:gYearMonth'},
        {'@name': 'xs:gYear'},
        {'@name': 'xs:gMonthDay'},
        {'@name': 'xs:gDay'},
        {'@name': 'xs:gMonth'},
        {'@name': 'xs:string'},
        {'@name': 'xs:boolean'},
        {'@name': 'xs:base64Binary'},
        {'@name': 'xs:hexBinary'},
        {'@name': 'xs:float'},
        {'@name': 'xs:decimal'},
        {'@name': 'xs:integer'},
        {'@name': 'xs:nonPositiveInteger'},
        {'@name': 'xs:negativeInteger'},
        {'@name': 'xs:int'},
        {'@name': 'xs:short'},
        {'@name': 'xs:byte'},
        {'@name': 'xs:nonNegativeInteger'},
        {'@name': 'xs:unsignedLong'},
        {'@name': 'xs:positiveInteger'},
        {'@name': 'xs:unsignedInt'},
        {'@name': 'xs:unsignedShort'},
        {'@name': 'xs:unsignedByte'},
        {'@name': 'xs:double'},
        {'@name': 'xs:anyURI'},
        {'@name': 'xs:QName'},
       {'@name': 'xs:NOTATION'},
]
def extract_paths(tree, search_val, path_offset, filter_offset=None, filter_value=None):
    if filter_offset is not None and filter_value is not None:
        extract = [(tuple(k['path'][:path_offset]), k['value']) for k in key_scan_obj(tree, search_val) if k['path'][filter_offset].lower()==filter_value]
    else:
        extract = [(tuple(k['path'][:path_offset]), k['value']) for k in key_scan_obj(tree, search_val) ]
    return extract


def parse_xsd(xsd_bytes):
    xsd_d = xmltodict.parse(xsd_bytes)
    xsd_d['xs:schema']['xs:primitiveType']=prims
    raw_names_d = dict(extract_paths(xsd_d['xs:schema'], "@name", -1))
    raw_bases_d = dict(extract_paths(xsd_d['xs:schema'], "@base", -2, -2, 'xs:restriction') + extract_paths(xsd_d['xs:schema'], "@base", -3, -2, 'xs:extension'))
    raw_types_d = dict(extract_paths(xsd_d['xs:schema'], "@type", -1))
    raw_primitives_d = dict(extract_paths(xsd_d['xs:schema'], "@base", -1, 0, 'xs:primitiveType'))
    raw_primitives_labels_d = {k:"_terminal_" for k,v in raw_primitives_d.items()}

    refs_d = dict([(k,v) for k,v in raw_names_d.items() if not any([p in ['xs:element','xs:attribute'] for p in k[-2:]])])

    # This contains all the specifications required to build the model, keys, (names, types, contextual_clues) TBD: Cardinalities
    specification_d = {k:(v,
                      raw_types_d.get(k, raw_bases_d.get(k,raw_primitives_labels_d.get(k,"_container_"))),
                      "_ref_" if k in refs_d.keys() else "_spec_") for k,v in raw_names_d.items()}

    ref_keys = {v[0]:(k,v[1],v[2]) for k,v in specification_d.items() if v[2]=='_ref_'}
    return raw_names_d, raw_bases_d, raw_types_d, raw_primitives_d, raw_primitives_labels_d, ref_keys, specification_d


def build_(root, spec_d, obj=None):
    ref_keys = {v[0]:(k,v[1],v[2]) for k,v in spec_d.items() if v[2]=='_ref_'}
    if obj is None:
        obj={}
    name, v_type, clue = spec_d.get(root)
    #print(root, name, v_type, clue)
    #print()
    content=[]
    if clue == '_ref_':
        #print("R")
        if v_type == "_container_":
            #print("C")
            for k in spec_d.keys():
                if k[0:len(root)]==root and k!=root:
                    content.append(build_(k, spec_d))
        elif v_type != "_container_" and v_type != "_terminal_":
            #print("!", v_type, clue)
            lookahead = ref_keys.get(v_type)
            if lookahead[1] == "_terminal_":
                content={v_type:{}}
            else:
                content=build_( lookahead[0], spec_d)
        else:
            content=name
    elif clue == '_spec_':

        #print (name, v_type, ref_keys.get(v_type))
        content=build_( ref_keys.get(v_type)[0], spec_d)

    else:
        assert False
        return name, v_type, clue
    obj[name]=content
    return obj

# %%
xsd_construct = parse_xsd(customer_xsd)

# %%
q = build_(('xs:element',), xsd_construct[6])

# %%
paths = traverse_object(q)

# %%
for p in paths[0:25]:
    print (p[-8:], len(p))
