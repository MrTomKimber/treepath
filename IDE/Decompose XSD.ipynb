# %%
import xmltodict
import os,sys
sys.path.append("../..")
sys.path.append("../../xsdviz")
import treepath.treepath as tp
from treepath.treepath import TreePath

from functools import reduce

import operator

from collections import Counter
from itertools import chain

import pandas as pd

import json

# %%
#with open("customer.xsd", "r") as xsdf:
filename = "pacs.008.001.09.xsd"
#filename = "2012_04_XMLSchema.xsd"
#filename = "test copy.xsd"

with open(filename, "r") as xsdf:
    customer_xsd = xsdf.read()
cust_d = xmltodict.parse(customer_xsd)

# %%
def access_dict(d,p):
    return reduce(operator.getitem, p , d)

def isnumeric(v):
    return isinstance(v, (int, float, complex)) and not isinstance(v, bool)

# %%
cust_tp = tp.TreePath(cust_d)

# %%
#import xsdparse

# %%
list(cust_d.keys())[0]
# Out:
# 'xs:schema'

# %%
self_namespace_prefix = list(cust_d.keys())[0].split(":")[0]

def prefix_set(prefix, pset):
    return {prefix + ":" + str(v) for v in pset}


# Define "static" data
xsprims = {'duration','dateTime','time','date','gYearMonth','gYear',
                'gMonthDay','gDay','gMonth','string','boolean','base64Binary',
                'hexBinary','float','decimal','integer','nonPositiveInteger',
                'negativeInteger','int','short','byte','nonNegativeInteger',
                'unsignedLong','positiveInteger','unsignedInt','unsignedShort',
                'unsignedByte','double','anyURI','QName','NOTATION'}



xsnameables = {"attribute", "attributeGroup","complexType", "element", 
                         "group", "key", "keyref", "notation", "simpleType", 
                         "unique", 'primitiveType'}

xsrefs = {"attribute", "attributeGroup", "element", "group", }
xstype_defs = {"complexType", "simpleType", "primitiveType" }

xscompound_defs = {"choice", "all", "sequence"}

primitives_set = prefix_set(self_namespace_prefix, xsprims)
nameable_xsd_elements = prefix_set(self_namespace_prefix, xsnameables)
ref_set = prefix_set(self_namespace_prefix, xsrefs)
type_definition_set = prefix_set(self_namespace_prefix, xstype_defs)

# %%
# Process XSD into ERD task steps
#1 Load XSD into malleable format

#2 Extract named objects

#3 Extract objects requiring references

#4 Loop over 3, updating object from #1 such that all named objects
#  are complete without any remaining reference updates. 

#5 Extract objects that define types, extensions and restrictions

#6 Reduce singular extensions and restrictions down to their singular/primitive types

#7 Identify objects that describe sequences and other multi-part objects 
#  and associate them with a named parent-type/element

#8 Create tree of joined sequences so as to result in a workable ERD with entities and joins
#  This tree would consist of nodes consisting of multi-part sequences, and elemental
#  types that themselves are pointers to other single-or-multi part sequences.

# %%
# Given a tree obj, and some child-tag used to identify nodes within that tree
# build an index used to link paths to their assigned names. 
# Since there's no guarantee of name-uniqueness, each name can refer to 
# one or more paths.

def build_path_index(obj, index_tag="@name"):
    index_d={}
    def store(k,v):
        if k in index_d:
            index_d[k].append(v)
        else:
            index_d[k]=[v]

    #for p in TreePath._iterPaths(obj):
    for p in TreePath._iterLeaves(obj):
        if p[-1]==index_tag:
            #print(p)
            store(access_dict(obj,p), p[:-1])
    return index_d


# Querying the pre-built path_index (see build_path_index) on some key value, 
# choose the path that most closely matches a source_path provided. 
# In practice, this means returning the name most likely to be in scope, 
# when there's some ambiguity in terms of which name to pick.
def return_closest_path_match(path_index_d, key, source_path):

    cand_paths = path_index_d.get(key)
    score_paths = []
    for e,p in enumerate(cand_paths):
        matching_path = TreePath._shortest_common_path([p, source_path])
        score_paths.append( (len(matching_path), len(source_path)-len(matching_path) ) )
    #print(cand_paths, score_paths)
    return cand_paths[score_paths.index(sorted([s for s in score_paths], key=lambda x : (x[0], x[1]))[-1])]

# %%
# 1) Get the things
#named_things = [p[:-1] for p in TreePath._iterPaths(cust_d) if p[-1]=="@name"]
def gen_labelled_path_dict(info_d, index_tag="@name"):
    things={}
    for name, paths in build_path_index(info_d, index_tag=index_tag).items():
        things[name]=[]
        for path in paths:
            for e,path_element in enumerate(path[::-1]):
                if path_element in nameable_xsd_elements:
                    thing_type=path_element
                    things[name].append((thing_type, path))
                    break
                else:
                    pass
                    
    return things

prims = [{"@name":t} for t in primitives_set]
cust_d[self_namespace_prefix+':schema'][self_namespace_prefix+':primitiveType']=prims

named_things=gen_labelled_path_dict(cust_d, index_tag="@name")
things_requiring_reference = build_path_index(cust_d, index_tag="@ref")

#for k in things_requiring_reference:
#    print (k, named_things[k], things_requiring_reference[k])

#referred_things = [p[:-1] for p in TreePath._iterPaths(cust_d) if p[-1]=="@ref"]
#len(named_things),len(referred_things)

# %%
all_named_types = set()
named_other_things = set()

for k,v in named_things.items():
    for vv in v:
        if vv[0] in type_definition_set:
            
            all_named_types.add((k, vv[0], tuple(vv[1])))
        else:
            named_other_things.add((k, vv[0], tuple(vv[1])))

            
all_named_types # these will become terminal nodes for type-matching.
# Out:
# {('AccountIdentification4Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 0)),
#  ('AccountSchemeName1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 1)),
#  ('ActiveCurrencyAndAmount',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 2)),
#  ('ActiveCurrencyAndAmount_SimpleType',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 0)),
#  ('ActiveCurrencyCode', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 1)),
#  ('ActiveOrHistoricCurrencyAndAmount',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 3)),
#  ('ActiveOrHistoricCurrencyAndAmount_SimpleType',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 2)),
#  ('ActiveOrHistoricCurrencyCode',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 3)),
#  ('AddressType2Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 4)),
#  ('AddressType3Choice', 'xs:complexType', ('xs:schema', 'xs:complexType', 4)),
#  ('AnyBICDec2014Identifier',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 5)),
#  ('BICFIDec2014Identifier',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 6)),
#  ('BaseOneRate', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 7)),
#  ('BatchBookingIndicator', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 8)),
#  ('BranchAndFinancialInstitutionIdentification6',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 5)),
#  ('BranchData3', 'xs:complexType', ('xs:schema', 'xs:complexType', 6)),
#  ('CashAccount38', 'xs:complexType', ('xs:schema', 'xs:complexType', 7)),
#  ('CashAccountType2Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 8)),
#  ('CategoryPurpose1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 9)),
#  ('ChargeBearerType1Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 9)),
#  ('Charges7', 'xs:complexType', ('xs:schema', 'xs:complexType', 10)),
#  ('ClearingChannel2Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 10)),
#  ('ClearingSystemIdentification2Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 11)),
#  ('ClearingSystemIdentification3Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 12)),
#  ('ClearingSystemMemberIdentification2',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 13)),
#  ('Contact4', 'xs:complexType', ('xs:schema', 'xs:complexType', 14)),
#  ('CountryCode', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 11)),
#  ('CreditDebitCode', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 12)),
#  ('CreditTransferMandateData1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 15)),
#  ('CreditTransferTransaction43',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 16)),
#  ('CreditorReferenceInformation2',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 17)),
#  ('CreditorReferenceType1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 18)),
#  ('CreditorReferenceType2',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 19)),
#  ('DateAndPlaceOfBirth1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 20)),
#  ('DatePeriod2', 'xs:complexType', ('xs:schema', 'xs:complexType', 21)),
#  ('DecimalNumber', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 13)),
#  ('DiscountAmountAndType1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 22)),
#  ('DiscountAmountType1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 23)),
#  ('Document', 'xs:complexType', ('xs:schema', 'xs:complexType', 24)),
#  ('DocumentAdjustment1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 25)),
#  ('DocumentLineIdentification1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 26)),
#  ('DocumentLineInformation1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 27)),
#  ('DocumentLineType1', 'xs:complexType', ('xs:schema', 'xs:complexType', 28)),
#  ('DocumentLineType1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 29)),
#  ('DocumentType3Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 14)),
#  ('DocumentType6Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 15)),
#  ('Exact2NumericText', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 16)),
#  ('Exact4AlphaNumericText',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 17)),
#  ('ExternalAccountIdentification1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 18)),
#  ('ExternalCashAccountType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 19)),
#  ('ExternalCashClearingSystem1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 20)),
#  ('ExternalCategoryPurpose1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 21)),
#  ('ExternalClearingSystemIdentification1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 22)),
#  ('ExternalCreditorAgentInstruction1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 23)),
#  ('ExternalDiscountAmountType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 24)),
#  ('ExternalDocumentLineType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 25)),
#  ('ExternalFinancialInstitutionIdentification1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 26)),
#  ('ExternalGarnishmentType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 27)),
#  ('ExternalLocalInstrument1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 28)),
#  ('ExternalMandateSetupReason1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 29)),
#  ('ExternalOrganisationIdentification1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 30)),
#  ('ExternalPersonIdentification1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 31)),
#  ('ExternalProxyAccountType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 32)),
#  ('ExternalPurpose1Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 33)),
#  ('ExternalServiceLevel1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 34)),
#  ('ExternalTaxAmountType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 35)),
#  ('FIToFICustomerCreditTransferV09',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 30)),
#  ('FinancialIdentificationSchemeName1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 31)),
#  ('FinancialInstitutionIdentification18',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 32)),
#  ('Frequency36Choice', 'xs:complexType', ('xs:schema', 'xs:complexType', 33)),
#  ('Frequency6Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 36)),
#  ('FrequencyAndMoment1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 34)),
#  ('FrequencyPeriod1', 'xs:complexType', ('xs:schema', 'xs:complexType', 35)),
#  ('Garnishment3', 'xs:complexType', ('xs:schema', 'xs:complexType', 36)),
#  ('GarnishmentType1', 'xs:complexType', ('xs:schema', 'xs:complexType', 37)),
#  ('GarnishmentType1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 38)),
#  ('GenericAccountIdentification1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 39)),
#  ('GenericFinancialIdentification1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 40)),
#  ('GenericIdentification30',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 41)),
#  ('GenericOrganisationIdentification1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 42)),
#  ('GenericPersonIdentification1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 43)),
#  ('GroupHeader93', 'xs:complexType', ('xs:schema', 'xs:complexType', 44)),
#  ('IBAN2007Identifier', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 37)),
#  ('ISODate', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 38)),
#  ('ISODateTime', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 39)),
#  ('ISOTime', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 40)),
#  ('Instruction4Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 41)),
#  ('InstructionForCreditorAgent3',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 45)),
#  ('InstructionForNextAgent1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 46)),
#  ('LEIIdentifier', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 42)),
#  ('LocalInstrument2Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 47)),
#  ('MandateClassification1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 48)),
#  ('MandateClassification1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 43)),
#  ('MandateSetupReason1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 49)),
#  ('MandateTypeInformation2',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 50)),
#  ('Max10KBinary', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 44)),
#  ('Max10Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 45)),
#  ('Max128Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 46)),
#  ('Max140Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 47)),
#  ('Max15NumericText', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 48)),
#  ('Max16Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 49)),
#  ('Max2048Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 50)),
#  ('Max34Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 51)),
#  ('Max350Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 52)),
#  ('Max35Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 53)),
#  ('Max4Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 54)),
#  ('Max70Text', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 55)),
#  ('NameAndAddress16', 'xs:complexType', ('xs:schema', 'xs:complexType', 51)),
#  ('NamePrefix2Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 56)),
#  ('Number', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 57)),
#  ('OrganisationIdentification29',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 52)),
#  ('OrganisationIdentificationSchemeName1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 53)),
#  ('OtherContact1', 'xs:complexType', ('xs:schema', 'xs:complexType', 54)),
#  ('Party38Choice', 'xs:complexType', ('xs:schema', 'xs:complexType', 55)),
#  ('PartyIdentification135',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 56)),
#  ('PaymentIdentification13',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 57)),
#  ('PaymentTypeInformation28',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 58)),
#  ('PercentageRate', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 58)),
#  ('PersonIdentification13',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 59)),
#  ('PersonIdentificationSchemeName1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 60)),
#  ('PhoneNumber', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 59)),
#  ('PostalAddress24', 'xs:complexType', ('xs:schema', 'xs:complexType', 61)),
#  ('PreferredContactMethod1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 60)),
#  ('Priority2Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 61)),
#  ('Priority3Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 62)),
#  ('ProxyAccountIdentification1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 62)),
#  ('ProxyAccountType1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 63)),
#  ('Purpose2Choice', 'xs:complexType', ('xs:schema', 'xs:complexType', 64)),
#  ('ReferredDocumentInformation7',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 65)),
#  ('ReferredDocumentType3Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 66)),
#  ('ReferredDocumentType4',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 67)),
#  ('RegulatoryAuthority2',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 68)),
#  ('RegulatoryReporting3',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 69)),
#  ('RegulatoryReportingType1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 63)),
#  ('RemittanceAmount2', 'xs:complexType', ('xs:schema', 'xs:complexType', 70)),
#  ('RemittanceAmount3', 'xs:complexType', ('xs:schema', 'xs:complexType', 71)),
#  ('RemittanceInformation16',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 72)),
#  ('RemittanceLocation7',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 73)),
#  ('RemittanceLocationData1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 74)),
#  ('RemittanceLocationMethod2Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 64)),
#  ('ServiceLevel8Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 75)),
#  ('SettlementDateTimeIndication1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 76)),
#  ('SettlementInstruction7',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 77)),
#  ('SettlementMethod1Code',
#   'xs:simpleType',
#   ('xs:schema', 'xs:simpleType', 65)),
#  ('SettlementTimeRequest2',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 78)),
#  ('StructuredRegulatoryReporting3',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 79)),
#  ('StructuredRemittanceInformation16',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 80)),
#  ('SupplementaryData1', 'xs:complexType', ('xs:schema', 'xs:complexType', 81)),
#  ('SupplementaryDataEnvelope1',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 82)),
#  ('TaxAmount2', 'xs:complexType', ('xs:schema', 'xs:complexType', 83)),
#  ('TaxAmountAndType1', 'xs:complexType', ('xs:schema', 'xs:complexType', 84)),
#  ('TaxAmountType1Choice',
#   'xs:complexType',
#   ('xs:schema', 'xs:complexType', 85)),
#  ('TaxAuthorisation1', 'xs:complexType', ('xs:schema', 'xs:complexType', 86)),
#  ('TaxInformation7', 'xs:complexType', ('xs:schema', 'xs:complexType', 87)),
#  ('TaxInformation8', 'xs:complexType', ('xs:schema', 'xs:complexType', 88)),
#  ('TaxParty1', 'xs:complexType', ('xs:schema', 'xs:complexType', 89)),
#  ('TaxParty2', 'xs:complexType', ('xs:schema', 'xs:complexType', 90)),
#  ('TaxPeriod2', 'xs:complexType', ('xs:schema', 'xs:complexType', 91)),
#  ('TaxRecord2', 'xs:complexType', ('xs:schema', 'xs:complexType', 92)),
#  ('TaxRecordDetails2', 'xs:complexType', ('xs:schema', 'xs:complexType', 93)),
#  ('TaxRecordPeriod1Code', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 66)),
#  ('TrueFalseIndicator', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 67)),
#  ('UUIDv4Identifier', 'xs:simpleType', ('xs:schema', 'xs:simpleType', 68)),
#  ('xs:NOTATION', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 21)),
#  ('xs:QName', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 23)),
#  ('xs:anyURI', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 22)),
#  ('xs:base64Binary', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 1)),
#  ('xs:boolean', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 18)),
#  ('xs:byte', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 29)),
#  ('xs:date', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 26)),
#  ('xs:dateTime', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 13)),
#  ('xs:decimal', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 6)),
#  ('xs:double', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 16)),
#  ('xs:duration', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 27)),
#  ('xs:float', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 20)),
#  ('xs:gDay', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 10)),
#  ('xs:gMonth', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 24)),
#  ('xs:gMonthDay', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 0)),
#  ('xs:gYear', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 8)),
#  ('xs:gYearMonth', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 12)),
#  ('xs:hexBinary', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 3)),
#  ('xs:int', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 14)),
#  ('xs:integer', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 7)),
#  ('xs:negativeInteger',
#   'xs:primitiveType',
#   ('xs:schema', 'xs:primitiveType', 19)),
#  ('xs:nonNegativeInteger',
#   'xs:primitiveType',
#   ('xs:schema', 'xs:primitiveType', 2)),
#  ('xs:nonPositiveInteger',
#   'xs:primitiveType',
#   ('xs:schema', 'xs:primitiveType', 4)),
#  ('xs:positiveInteger',
#   'xs:primitiveType',
#   ('xs:schema', 'xs:primitiveType', 17)),
#  ('xs:short', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 25)),
#  ('xs:string', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 11)),
#  ('xs:time', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 15)),
#  ('xs:unsignedByte',
#   'xs:primitiveType',
#   ('xs:schema', 'xs:primitiveType', 28)),
#  ('xs:unsignedInt', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 5)),
#  ('xs:unsignedLong', 'xs:primitiveType', ('xs:schema', 'xs:primitiveType', 9)),
#  ('xs:unsignedShort',
#   'xs:primitiveType',
#   ('xs:schema', 'xs:primitiveType', 30))}

# %%
#cust_tp.data['xs:schema']['xs:element'][1]['xs:complexType'][ 'xs:sequence']['xs:element'][0]

# %%
cust_tp.data[self_namespace_prefix+':schema'][self_namespace_prefix+':primitiveType']=prims

# %%
cust_tp.data['xs:schema']['xs:element']
# Out:
# {'@name': 'Document', '@type': 'Document'}

# %%
named_things=gen_labelled_path_dict(cust_tp.data, index_tag="@name")
things_requiring_reference = build_path_index(cust_tp.data, index_tag="@ref")


all_named_types = set()
named_other_things = set()

for k,v in named_things.items():
    for vv in v:
        if vv[0] in type_definition_set:
            
            all_named_types.add((k, vv[0], tuple(vv[1])))
        else:
            named_other_things.add((k, vv[0], tuple(vv[1])))

            
Counter([t[1] for t in named_other_things]) # these will become terminal nodes for type-matching.
# Out:
# Counter({'xs:element': 368, 'xs:attribute': 2})

# %%
Counter([t[1] for t in all_named_types])
# Out:
# Counter({'xs:complexType': 94, 'xs:primitiveType': 31, 'xs:simpleType': 69})

# %%
def return_longest_matching_ancestor(q, paths):
    
    scores=[]
    lq = len(q)
    for t,path in enumerate(paths):
        maxe=0
        for e,p in enumerate(path[:lq]):
            if q[e]!=p:
                r=e
                break
            r=e+1
        scores.append(r-len(path))
    ms = max(scores)
#    return paths
#    return scores
    return [paths[e] for e,s in enumerate(scores) if s==ms ]

# %%
named_nodes = list(chain([(k, p[0], p[1], access_dict(cust_tp.data,p[1])) for k,t in named_things.items() for p in t]))

# %%
named_objects_df = pd.DataFrame(named_nodes, columns=["Name", "Type", "Path", "Obj"])

named_objects_df.groupby("Type").agg(len)
# Out:
#                   Name  Path  Obj
# Type
# xs:attribute         2     2    2
# xs:complexType      94    94   94
# xs:element         368   368  368
# xs:primitiveType    31    31   31
# xs:simpleType       69    69   69

# %%
q_df = named_objects_df.set_index(["Name", "Type"]).sort_index()
q_df['_resolved']=False

# %%
q_df#loc[("TCRMExtension", "xs:element")]
# Out:
#                                                                                                   Path  \
# Name                               Type
# AccountIdentification4Choice       xs:complexType                       [xs:schema, xs:complexType, 0]
# AccountSchemeName1Choice           xs:complexType                       [xs:schema, xs:complexType, 1]
# AccptncDtTm                        xs:element        [xs:schema, xs:complexType, 16, xs:sequence, x...
# ActiveCurrencyAndAmount            xs:complexType                       [xs:schema, xs:complexType, 2]
# ActiveCurrencyAndAmount_SimpleType xs:simpleType                         [xs:schema, xs:simpleType, 0]
# ...                                                                                                ...
# xs:time                            xs:primitiveType                  [xs:schema, xs:primitiveType, 15]
# xs:unsignedByte                    xs:primitiveType                  [xs:schema, xs:primitiveType, 28]
# xs:unsignedInt                     xs:primitiveType                   [xs:schema, xs:primitiveType, 5]
# xs:unsignedLong                    xs:primitiveType                   [xs:schema, xs:primitiveType, 9]
# xs:unsignedShort                   xs:primitiveType                  [xs:schema, xs:primitiveType, 30]
#
#                                                                                                    Obj  \
# Name                               Type
# AccountIdentification4Choice       xs:complexType    {'@name': 'AccountIdentification4Choice', 'xs:...
# AccountSchemeName1Choice           xs:complexType    {'@name': 'AccountSchemeName1Choice', 'xs:choi...
# AccptncDtTm                        xs:element        {'@maxOccurs': '1', '@minOccurs': '0', '@name'...
# ActiveCurrencyAndAmount            xs:complexType    {'@name': 'ActiveCurrencyAndAmount', 'xs:simpl...
# ActiveCurrencyAndAmount_SimpleType xs:simpleType     {'@name': 'ActiveCurrencyAndAmount_SimpleType'...
# ...                                                                                                ...
# xs:time                            xs:primitiveType                               {'@name': 'xs:time'}
# xs:unsignedByte                    xs:primitiveType                       {'@name': 'xs:unsignedByte'}
# xs:unsignedInt                     xs:primitiveType                        {'@name': 'xs:unsignedInt'}
# xs:unsignedLong                    xs:primitiveType                       {'@name': 'xs:unsignedLong'}
# xs:unsignedShort                   xs:primitiveType                      {'@name': 'xs:unsignedShort'}
#
#                                                      _resolved
# Name                               Type
# AccountIdentification4Choice       xs:complexType        False
# AccountSchemeName1Choice           xs:complexType        False
# AccptncDtTm                        xs:element            False
# ActiveCurrencyAndAmount            xs:complexType        False
# ActiveCurrencyAndAmount_SimpleType xs:simpleType         False
# ...                                                        ...
# xs:time                            xs:primitiveType      False
# xs:unsignedByte                    xs:primitiveType      False
# xs:unsignedInt                     xs:primitiveType      False
# xs:unsignedLong                    xs:primitiveType      False
# xs:unsignedShort                   xs:primitiveType      False
#
# [564 rows x 3 columns]

# %%
leaf_gen = cust_tp._iterLeaves(cust_tp.data)
named_leaves=set()
for p in leaf_gen:
    if p[-1]=="@name":
        named_leaves.add(tuple(p[:-1]))
len(named_leaves)
# Out:
# 564

# %%
# A named thing exists at the end of a specific path. Some named things can be resolved as individual items 
# without referencing something else, other things require de-referencing before they can be worked on.
# Figuring out what does and does not need de-referencing can be done using the following algorithm:
# 1) Is it a primitive type?
# 2) Is it a simpleType
# 3) Is it an element consisting of simpleContent
### ... add more here ...
## https://learn.microsoft.com/en-us/previous-versions/dotnet/netframework-4.0/ms256067(v=vs.100)
    
    
def simpleContent_proc(ix_dummy, vals, resolver):
    pass

def complexContent_proc(ix_dummy, vals, resolver):
    pass


def complexType_proc(ix, vals, resolver):
    #simpleContent, complexContent, group, all, choice, sequence, attribute, attributeGroup, anyAttribute
    
    return False,0

# This is an anonimous type, so should always be called in the context of some parent that will 
# harvest and process the returned content.
# The vals parameter should contain a Series in which the obj column contains the specific restriction
# for processing
def restriction_proc(ix, vals, resolver):
    obj = vals['Obj']
    base_name = obj['@base']
    possible_base_types = ["xs:primitiveType", "xs:simpleType"]
    is_resolvable=False
    pointer=None
    if any([(base_name,bt) in resolver.keys() for bt in possible_base_types]):
        is_resolvable=True
        pointer=[(base_name,bt) for bt in possible_base_types if (base_name,bt) in resolver.keys() ]
    else:
        pass
    return is_resolvable, pointer

def extension_proc(ix, vals, resolver):
    # The extension will fetch, as a base, some content located elsewhere...
    # Likely appears as part of a complexType section, but could be under a simpleContent section also
    obj = vals['Obj']
    base_name = obj['@base']
    possible_base_types = ["xs:primitiveType", "xs:simpleType", "xs:complexType"]
    is_resolvable=False
    pointer=None
    if any([(base_name,bt) in resolver.keys() for bt in possible_base_types]):
        is_resolvable=True
        pointer=[(base_name,bt) for bt in possible_base_types if (base_name,bt) in resolver.keys() ]
    else:
        pass
    return is_resolvable, pointer
    
def simpleType_proc(ix, vals, resolver):
    # If this is a simpleType, it should consist only of references to primitives - or extensions of same
    obj = vals['Obj']
    is_resolvable=False
    pointer = None
    if 'xs:restriction' in obj.keys():
        base_name = obj['xs:restriction']['@base']
        possible_base_types = ["xs:primitiveType", "xs:simpleType"]
        pass_series = pd.Series(vals)
        pass_series['Obj']=obj['xs:restriction']
        pass_series['Path']=vals['Path'].extend('xs:restriction')
        is_resolvable, pointer = restriction_proc(ix, pass_series, resolver)
    elif 'xs:extension' in obj.keys():
        print(obj)
        print("Simple Type shouldn't contain an extension, quitting.")
        
    elif 'xs:union' in obj.keys():
        print(obj)
        print("Union element not yet implemented")
        assert False
        
    elif 'xs:list' in obj.keys():
        print(obj)
        print("List element not yet implemented")
        assert False
        
    else:
        print(obj.keys())
        assert False
    return is_resolvable,pointer

def element_proc(ix, vals,resolver):
    return False,0

def attribute_proc(ix, vals, resolver):
    print(vals['Obj'])
    obj = vals['Obj']
    is_resolvable=False
    pointer = None
    possible_attribute_datatypes = ["xs:primitiveType"]
    if "@type" in obj.keys():
        type_name = obj['@type']
    else:
        type_name = None
    if any([(type_name,bt) in resolver.keys() for bt in possible_attribute_datatypes]):
        is_resolvable=True
        pointer=[(type_name,bt) for bt in possible_attribute_datatypes if (type_name,bt) in resolver.keys() ]
    return is_resolvable,pointer

def primitiveType_proc(ix, vals,resolver):
    is_resolvable=True
    #print(vals['obj'])
    return is_resolvable, "primitive"
    
def unknown_proc(ix, vals,resolver):
    print ("Unknown!", ix, vals)
    assert False


type_function_lookup =  {"xs:complexType" : complexType_proc, 
                         "xs:simpleType" : simpleType_proc, 
                         "xs:element" : element_proc, 
                         "xs:attribute" : attribute_proc, 
                         "xs:primitiveType" : primitiveType_proc, 
                     }


resolver = {}
finished=False
ii=0
while not finished:
    ii+=1
    print("Iteration ", ii)
    for i,r in q_df.iterrows():
        print(i)
        if r['_resolved']==False:
            p_func = type_function_lookup.get(i[1], unknown_proc)
            r,v = p_func(i,r,resolver)
        if r is True:
            resolver[i]=r,v
    if len([v for v in resolver.values() if v[0]])==len(q_df):
        
        finished=True
    print(len([v for v in resolver.values() if v[0]]))
    if ii > 5:
        finished=True
resolver_df = pd.DataFrame(resolver).T
# Out:
# Iteration  1
# ('AccountIdentification4Choice', 'xs:complexType')
# ('AccountSchemeName1Choice', 'xs:complexType')
# ('AccptncDtTm', 'xs:element')
# ('ActiveCurrencyAndAmount', 'xs:complexType')
# ('ActiveCurrencyAndAmount_SimpleType', 'xs:simpleType')
# ('ActiveCurrencyCode', 'xs:simpleType')
# ('ActiveOrHistoricCurrencyAndAmount', 'xs:complexType')
# ('ActiveOrHistoricCurrencyAndAmount_SimpleType', 'xs:simpleType')
# ('ActiveOrHistoricCurrencyCode', 'xs:simpleType')
# ('AddressType2Code', 'xs:simpleType')
# ('AddressType3Choice', 'xs:complexType')
# ('AddtlInf', 'xs:element')
# ('AddtlInf', 'xs:element')
# ('AddtlRmtInf', 'xs:element')
# ('AdjstmntAmtAndRsn', 'xs:element')
# ('AdjstmntAmtAndRsn', 'xs:element')
# ('AdmstnZone', 'xs:element')
# ('AdmstnZone', 'xs:element')
# ('Adr', 'xs:element')
# ('AdrLine', 'xs:element')
# ('AdrTp', 'xs:element')
# ('Agt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('AnyBIC', 'xs:element')
# ('AnyBICDec2014Identifier', 'xs:simpleType')
# ('Authrty', 'xs:element')
# ('Authstn', 'xs:element')
# ('BICFI', 'xs:element')
# ('BICFIDec2014Identifier', 'xs:simpleType')
# ('BaseOneRate', 'xs:simpleType')
# ('BatchBookingIndicator', 'xs:simpleType')
# ('BirthDt', 'xs:element')
# ('BldgNb', 'xs:element')
# ('BldgNm', 'xs:element')
# ('BranchAndFinancialInstitutionIdentification6', 'xs:complexType')
# ('BranchData3', 'xs:complexType')
# ('BrnchId', 'xs:element')
# ('BtchBookg', 'xs:element')
# ('CLSTm', 'xs:element')
# ('CashAccount38', 'xs:complexType')
# ('CashAccountType2Choice', 'xs:complexType')
# ('CategoryPurpose1Choice', 'xs:complexType')
# ('Ccy', 'xs:attribute')
# {'@name': 'Ccy', '@type': 'ActiveCurrencyCode', '@use': 'required'}
# ('Ccy', 'xs:attribute')
# {'@name': 'Ccy', '@type': 'ActiveOrHistoricCurrencyCode', '@use': 'required'}
# ('Ccy', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdtDbtInd', 'xs:element')
# ('CdtDtTm', 'xs:element')
# ('CdtNoteAmt', 'xs:element')
# ('CdtNoteAmt', 'xs:element')
# ('CdtTrfTxInf', 'xs:element')
# ('Cdtr', 'xs:element')
# ('Cdtr', 'xs:element')
# ('Cdtr', 'xs:element')
# ('CdtrAcct', 'xs:element')
# ('CdtrAgt', 'xs:element')
# ('CdtrAgtAcct', 'xs:element')
# ('CdtrRefInf', 'xs:element')
# ('CertId', 'xs:element')
# ('ChanlTp', 'xs:element')
# ('ChargeBearerType1Code', 'xs:simpleType')
# ('Charges7', 'xs:complexType')
# ('ChrgBr', 'xs:element')
# ('ChrgsInf', 'xs:element')
# ('CityOfBirth', 'xs:element')
# ('ClearingChannel2Code', 'xs:simpleType')
# ('ClearingSystemIdentification2Choice', 'xs:complexType')
# ('ClearingSystemIdentification3Choice', 'xs:complexType')
# ('ClearingSystemMemberIdentification2', 'xs:complexType')
# ('ClrChanl', 'xs:element')
# ('ClrSys', 'xs:element')
# ('ClrSysId', 'xs:element')
# ('ClrSysMmbId', 'xs:element')
# ('ClrSysRef', 'xs:element')
# ('Clssfctn', 'xs:element')
# ('CntPerPrd', 'xs:element')
# ('Contact4', 'xs:complexType')
# ('CountryCode', 'xs:simpleType')
# ('CreDtTm', 'xs:element')
# ('CreditDebitCode', 'xs:simpleType')
# ('CreditTransferMandateData1', 'xs:complexType')
# ('CreditTransferTransaction43', 'xs:complexType')
# ('CreditorReferenceInformation2', 'xs:complexType')
# ('CreditorReferenceType1Choice', 'xs:complexType')
# ('CreditorReferenceType2', 'xs:complexType')
# ('CtctDtls', 'xs:element')
# ('Ctgy', 'xs:element')
# ('CtgyDtls', 'xs:element')
# ('CtgyPurp', 'xs:element')
# ('CtgyPurp', 'xs:element')
# ('CtrlSum', 'xs:element')
# ('Ctry', 'xs:element')
# ('Ctry', 'xs:element')
# ('Ctry', 'xs:element')
# ('CtryOfBirth', 'xs:element')
# ('CtryOfRes', 'xs:element')
# ('CtrySubDvsn', 'xs:element')
# ('DateAndPlaceOfBirth1', 'xs:complexType')
# ('DatePeriod2', 'xs:complexType')
# ('DbtCdtRptgInd', 'xs:element')
# ('DbtDtTm', 'xs:element')
# ('Dbtr', 'xs:element')
# ('Dbtr', 'xs:element')
# ('Dbtr', 'xs:element')
# ('DbtrAcct', 'xs:element')
# ('DbtrAgt', 'xs:element')
# ('DbtrAgtAcct', 'xs:element')
# ('DbtrSts', 'xs:element')
# ('DecimalNumber', 'xs:simpleType')
# ('Dept', 'xs:element')
# ('Dept', 'xs:element')
# ('Desc', 'xs:element')
# ('DiscountAmountAndType1', 'xs:complexType')
# ('DiscountAmountType1Choice', 'xs:complexType')
# ('Document', 'xs:complexType')
# ('Document', 'xs:element')
# ('DocumentAdjustment1', 'xs:complexType')
# ('DocumentLineIdentification1', 'xs:complexType')
# ('DocumentLineInformation1', 'xs:complexType')
# ('DocumentLineType1', 'xs:complexType')
# ('DocumentLineType1Choice', 'xs:complexType')
# ('DocumentType3Code', 'xs:simpleType')
# ('DocumentType6Code', 'xs:simpleType')
# ('DscntApldAmt', 'xs:element')
# ('DscntApldAmt', 'xs:element')
# ('DstrctNm', 'xs:element')
# ('Dt', 'xs:element')
# ('Dt', 'xs:element')
# ('Dt', 'xs:element')
# ('Dt', 'xs:element')
# ('DtAndPlcOfBirth', 'xs:element')
# ('DtOfSgntr', 'xs:element')
# ('DtOfVrfctn', 'xs:element')
# ('Dtls', 'xs:element')
# ('Dtls', 'xs:element')
# ('DuePyblAmt', 'xs:element')
# ('DuePyblAmt', 'xs:element')
# ('ElctrncAdr', 'xs:element')
# ('ElctrncSgntr', 'xs:element')
# ('EmailAdr', 'xs:element')
# ('EmailPurp', 'xs:element')
# ('EndToEndId', 'xs:element')
# ('Envlp', 'xs:element')
# ('Exact2NumericText', 'xs:simpleType')
# ('Exact4AlphaNumericText', 'xs:simpleType')
# ('ExternalAccountIdentification1Code', 'xs:simpleType')
# ('ExternalCashAccountType1Code', 'xs:simpleType')
# ('ExternalCashClearingSystem1Code', 'xs:simpleType')
# ('ExternalCategoryPurpose1Code', 'xs:simpleType')
# ('ExternalClearingSystemIdentification1Code', 'xs:simpleType')
# ('ExternalCreditorAgentInstruction1Code', 'xs:simpleType')
# ('ExternalDiscountAmountType1Code', 'xs:simpleType')
# ('ExternalDocumentLineType1Code', 'xs:simpleType')
# ('ExternalFinancialInstitutionIdentification1Code', 'xs:simpleType')
# ('ExternalGarnishmentType1Code', 'xs:simpleType')
# ('ExternalLocalInstrument1Code', 'xs:simpleType')
# ('ExternalMandateSetupReason1Code', 'xs:simpleType')
# ('ExternalOrganisationIdentification1Code', 'xs:simpleType')
# ('ExternalPersonIdentification1Code', 'xs:simpleType')
# ('ExternalProxyAccountType1Code', 'xs:simpleType')
# ('ExternalPurpose1Code', 'xs:simpleType')
# ('ExternalServiceLevel1Code', 'xs:simpleType')
# ('ExternalTaxAmountType1Code', 'xs:simpleType')
# ('FIToFICstmrCdtTrf', 'xs:element')
# ('FIToFICustomerCreditTransferV09', 'xs:complexType')
# ('FaxNb', 'xs:element')
# ('FinInstnId', 'xs:element')
# ('FinancialIdentificationSchemeName1Choice', 'xs:complexType')
# ('FinancialInstitutionIdentification18', 'xs:complexType')
# ('Flr', 'xs:element')
# ('FmlyMdclInsrncInd', 'xs:element')
# ('FnlPmtDt', 'xs:element')
# ('FrDt', 'xs:element')
# ('FrTm', 'xs:element')
# ('FrToDt', 'xs:element')
# ('Frequency36Choice', 'xs:complexType')
# ('Frequency6Code', 'xs:simpleType')
# ('FrequencyAndMoment1', 'xs:complexType')
# ('FrequencyPeriod1', 'xs:complexType')
# ('FrmsCd', 'xs:element')
# ('Frqcy', 'xs:element')
# ('FrstPmtDt', 'xs:element')
# ('Garnishment3', 'xs:complexType')
# ('GarnishmentType1', 'xs:complexType')
# ('GarnishmentType1Choice', 'xs:complexType')
# ('GenericAccountIdentification1', 'xs:complexType')
# ('GenericFinancialIdentification1', 'xs:complexType')
# ('GenericIdentification30', 'xs:complexType')
# ('GenericOrganisationIdentification1', 'xs:complexType')
# ('GenericPersonIdentification1', 'xs:complexType')
# ('Grnshee', 'xs:element')
# ('GrnshmtAdmstr', 'xs:element')
# ('GrnshmtRmt', 'xs:element')
# ('GroupHeader93', 'xs:complexType')
# ('GrpHdr', 'xs:element')
# ('IBAN', 'xs:element')
# ('IBAN2007Identifier', 'xs:simpleType')
# ('ISODate', 'xs:simpleType')
# ('ISODateTime', 'xs:simpleType')
# ('ISOTime', 'xs:simpleType')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Inf', 'xs:element')
# ('InitgPty', 'xs:element')
# ('InstdAgt', 'xs:element')
# ('InstdAgt', 'xs:element')
# ('InstdAmt', 'xs:element')
# ('InstdRmbrsmntAgt', 'xs:element')
# ('InstdRmbrsmntAgtAcct', 'xs:element')
# ('InstgAgt', 'xs:element')
# ('InstgAgt', 'xs:element')
# ('InstgRmbrsmntAgt', 'xs:element')
# ('InstgRmbrsmntAgtAcct', 'xs:element')
# ('InstrForCdtrAgt', 'xs:element')
# ('InstrForNxtAgt', 'xs:element')
# ('InstrId', 'xs:element')
# ('InstrInf', 'xs:element')
# ('InstrInf', 'xs:element')
# ('InstrPrty', 'xs:element')
# ('Instruction4Code', 'xs:simpleType')
# ('InstructionForCreditorAgent3', 'xs:complexType')
# ('InstructionForNextAgent1', 'xs:complexType')
# ('IntrBkSttlmAmt', 'xs:element')
# ('IntrBkSttlmDt', 'xs:element')
# ('IntrBkSttlmDt', 'xs:element')
# ('IntrmyAgt1', 'xs:element')
# ('IntrmyAgt1Acct', 'xs:element')
# ('IntrmyAgt2', 'xs:element')
# ('IntrmyAgt2Acct', 'xs:element')
# ('IntrmyAgt3', 'xs:element')
# ('IntrmyAgt3Acct', 'xs:element')
# ('Invcee', 'xs:element')
# ('Invcr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('JobTitl', 'xs:element')
# ('LEI', 'xs:element')
# ('LEI', 'xs:element')
# ('LEI', 'xs:element')
# ('LEIIdentifier', 'xs:simpleType')
# ('LclInstrm', 'xs:element')
# ('LclInstrm', 'xs:element')
# ('LineDtls', 'xs:element')
# ('LocalInstrument2Choice', 'xs:complexType')
# ('MandateClassification1Choice', 'xs:complexType')
# ('MandateClassification1Code', 'xs:simpleType')
# ('MandateSetupReason1Choice', 'xs:complexType')
# ('MandateTypeInformation2', 'xs:complexType')
# ('Max10KBinary', 'xs:simpleType')
# ('Max10Text', 'xs:simpleType')
# ('Max128Text', 'xs:simpleType')
# ('Max140Text', 'xs:simpleType')
# ('Max15NumericText', 'xs:simpleType')
# ('Max16Text', 'xs:simpleType')
# ('Max2048Text', 'xs:simpleType')
# ('Max34Text', 'xs:simpleType')
# ('Max350Text', 'xs:simpleType')
# ('Max35Text', 'xs:simpleType')
# ('Max4Text', 'xs:simpleType')
# ('Max70Text', 'xs:simpleType')
# ('MmbId', 'xs:element')
# ('MndtId', 'xs:element')
# ('MndtRltdInf', 'xs:element')
# ('MobNb', 'xs:element')
# ('MplyeeTermntnInd', 'xs:element')
# ('MsgId', 'xs:element')
# ('Mtd', 'xs:element')
# ('Mtd', 'xs:element')
# ('Mtd', 'xs:element')
# ('NameAndAddress16', 'xs:complexType')
# ('NamePrefix2Code', 'xs:simpleType')
# ('Nb', 'xs:element')
# ('Nb', 'xs:element')
# ('NbOfTxs', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('NmPrfx', 'xs:element')
# ('Number', 'xs:simpleType')
# ('OrgId', 'xs:element')
# ('OrganisationIdentification29', 'xs:complexType')
# ('OrganisationIdentificationSchemeName1Choice', 'xs:complexType')
# ('OtherContact1', 'xs:complexType')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Party38Choice', 'xs:complexType')
# ('PartyIdentification135', 'xs:complexType')
# ('PaymentIdentification13', 'xs:complexType')
# ('PaymentTypeInformation28', 'xs:complexType')
# ('PercentageRate', 'xs:simpleType')
# ('PersonIdentification13', 'xs:complexType')
# ('PersonIdentificationSchemeName1Choice', 'xs:complexType')
# ('PhneNb', 'xs:element')
# ('PhoneNumber', 'xs:simpleType')
# ('PlcAndNm', 'xs:element')
# ('PmtId', 'xs:element')
# ('PmtTpInf', 'xs:element')
# ('PmtTpInf', 'xs:element')
# ('PoolgAdjstmntDt', 'xs:element')
# ('PostalAddress24', 'xs:complexType')
# ('Prd', 'xs:element')
# ('Prd', 'xs:element')
# ('Prd', 'xs:element')
# ('PreferredContactMethod1Code', 'xs:simpleType')
# ('PrefrdMtd', 'xs:element')
# ('Priority2Code', 'xs:simpleType')
# ('Priority3Code', 'xs:simpleType')
# ('ProxyAccountIdentification1', 'xs:complexType')
# ('ProxyAccountType1Choice', 'xs:complexType')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('PrvcOfBirth', 'xs:element')
# ('PrvsInstgAgt1', 'xs:element')
# ('PrvsInstgAgt1Acct', 'xs:element')
# ('PrvsInstgAgt2', 'xs:element')
# ('PrvsInstgAgt2Acct', 'xs:element')
# ('PrvsInstgAgt3', 'xs:element')
# ('PrvsInstgAgt3Acct', 'xs:element')
# ('PrvtId', 'xs:element')
# ('Prxy', 'xs:element')
# ('PstBx', 'xs:element')
# ('PstCd', 'xs:element')
# ('PstlAdr', 'xs:element')
# ('PstlAdr', 'xs:element')
# ('PstlAdr', 'xs:element')
# ('PstlAdr', 'xs:element')
# ('PtInTm', 'xs:element')
# ('PtInTm', 'xs:element')
# ('Purp', 'xs:element')
# ('Purpose2Choice', 'xs:complexType')
# ('Rate', 'xs:element')
# ('Rcrd', 'xs:element')
# ('Rcrd', 'xs:element')
# ('Ref', 'xs:element')
# ('RefNb', 'xs:element')
# ('RefNb', 'xs:element')
# ('RefNb', 'xs:element')
# ('ReferredDocumentInformation7', 'xs:complexType')
# ('ReferredDocumentType3Choice', 'xs:complexType')
# ('ReferredDocumentType4', 'xs:complexType')
# ('RegnId', 'xs:element')
# ('RegnId', 'xs:element')
# ('RegulatoryAuthority2', 'xs:complexType')
# ('RegulatoryReporting3', 'xs:complexType')
# ('RegulatoryReportingType1Code', 'xs:simpleType')
# ('RemittanceAmount2', 'xs:complexType')
# ('RemittanceAmount3', 'xs:complexType')
# ('RemittanceInformation16', 'xs:complexType')
# ('RemittanceLocation7', 'xs:complexType')
# ('RemittanceLocationData1', 'xs:complexType')
# ('RemittanceLocationMethod2Code', 'xs:simpleType')
# ('RfrdDocAmt', 'xs:element')
# ('RfrdDocInf', 'xs:element')
# ('RgltryRptg', 'xs:element')
# ('RjctTm', 'xs:element')
# ('RltdDt', 'xs:element')
# ('RltdDt', 'xs:element')
# ('RltdRmtInf', 'xs:element')
# ('RmtId', 'xs:element')
# ('RmtInf', 'xs:element')
# ('RmtLctnDtls', 'xs:element')
# ('RmtdAmt', 'xs:element')
# ('RmtdAmt', 'xs:element')
# ('RmtdAmt', 'xs:element')
# ('Room', 'xs:element')
# ('Rsn', 'xs:element')
# ('Rsn', 'xs:element')
# ('Rspnsblty', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SeqNb', 'xs:element')
# ('SeqNb', 'xs:element')
# ('ServiceLevel8Choice', 'xs:complexType')
# ('SettlementDateTimeIndication1', 'xs:complexType')
# ('SettlementInstruction7', 'xs:complexType')
# ('SettlementMethod1Code', 'xs:simpleType')
# ('SettlementTimeRequest2', 'xs:complexType')
# ('SplmtryData', 'xs:element')
# ('SplmtryData', 'xs:element')
# ('Strd', 'xs:element')
# ('StrtNm', 'xs:element')
# ('StructuredRegulatoryReporting3', 'xs:complexType')
# ('StructuredRemittanceInformation16', 'xs:complexType')
# ('SttlmAcct', 'xs:element')
# ('SttlmInf', 'xs:element')
# ('SttlmMtd', 'xs:element')
# ('SttlmPrty', 'xs:element')
# ('SttlmTmIndctn', 'xs:element')
# ('SttlmTmReq', 'xs:element')
# ('SubDept', 'xs:element')
# ('SupplementaryData1', 'xs:complexType')
# ('SupplementaryDataEnvelope1', 'xs:complexType')
# ('SvcLvl', 'xs:element')
# ('SvcLvl', 'xs:element')
# ('Tax', 'xs:element')
# ('TaxAmount2', 'xs:complexType')
# ('TaxAmountAndType1', 'xs:complexType')
# ('TaxAmountType1Choice', 'xs:complexType')
# ('TaxAmt', 'xs:element')
# ('TaxAmt', 'xs:element')
# ('TaxAmt', 'xs:element')
# ('TaxAuthorisation1', 'xs:complexType')
# ('TaxId', 'xs:element')
# ('TaxId', 'xs:element')
# ('TaxInformation7', 'xs:complexType')
# ('TaxInformation8', 'xs:complexType')
# ('TaxParty1', 'xs:complexType')
# ('TaxParty2', 'xs:complexType')
# ('TaxPeriod2', 'xs:complexType')
# ('TaxRecord2', 'xs:complexType')
# ('TaxRecordDetails2', 'xs:complexType')
# ('TaxRecordPeriod1Code', 'xs:simpleType')
# ('TaxRmt', 'xs:element')
# ('TaxTp', 'xs:element')
# ('TaxTp', 'xs:element')
# ('TaxblBaseAmt', 'xs:element')
# ('ThrdRmbrsmntAgt', 'xs:element')
# ('ThrdRmbrsmntAgtAcct', 'xs:element')
# ('TillTm', 'xs:element')
# ('Titl', 'xs:element')
# ('ToDt', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('TrueFalseIndicator', 'xs:simpleType')
# ('TtlAmt', 'xs:element')
# ('TtlIntrBkSttlmAmt', 'xs:element')
# ('TtlTaxAmt', 'xs:element')
# ('TtlTaxAmt', 'xs:element')
# ('TtlTaxblBaseAmt', 'xs:element')
# ('TtlTaxblBaseAmt', 'xs:element')
# ('TwnLctnNm', 'xs:element')
# ('TwnNm', 'xs:element')
# ('TxId', 'xs:element')
# ('UETR', 'xs:element')
# ('UUIDv4Identifier', 'xs:simpleType')
# ('UltmtCdtr', 'xs:element')
# ('UltmtDbtr', 'xs:element')
# ('UltmtDbtr', 'xs:element')
# ('Ustrd', 'xs:element')
# ('XchgRate', 'xs:element')
# ('Yr', 'xs:element')
# ('xs:NOTATION', 'xs:primitiveType')
# ('xs:QName', 'xs:primitiveType')
# ('xs:anyURI', 'xs:primitiveType')
# ('xs:base64Binary', 'xs:primitiveType')
# ('xs:boolean', 'xs:primitiveType')
# ('xs:byte', 'xs:primitiveType')
# ('xs:date', 'xs:primitiveType')
# ('xs:dateTime', 'xs:primitiveType')
# ('xs:decimal', 'xs:primitiveType')
# ('xs:double', 'xs:primitiveType')
# ('xs:duration', 'xs:primitiveType')
# ('xs:float', 'xs:primitiveType')
# ('xs:gDay', 'xs:primitiveType')
# ('xs:gMonth', 'xs:primitiveType')
# ('xs:gMonthDay', 'xs:primitiveType')
# ('xs:gYear', 'xs:primitiveType')
# ('xs:gYearMonth', 'xs:primitiveType')
# ('xs:hexBinary', 'xs:primitiveType')
# ('xs:int', 'xs:primitiveType')
# ('xs:integer', 'xs:primitiveType')
# ('xs:negativeInteger', 'xs:primitiveType')
# ('xs:nonNegativeInteger', 'xs:primitiveType')
# ('xs:nonPositiveInteger', 'xs:primitiveType')
# ('xs:positiveInteger', 'xs:primitiveType')
# ('xs:short', 'xs:primitiveType')
# ('xs:string', 'xs:primitiveType')
# ('xs:time', 'xs:primitiveType')
# ('xs:unsignedByte', 'xs:primitiveType')
# ('xs:unsignedInt', 'xs:primitiveType')
# ('xs:unsignedLong', 'xs:primitiveType')
# ('xs:unsignedShort', 'xs:primitiveType')
# 31
# Iteration  2
# ('AccountIdentification4Choice', 'xs:complexType')
# ('AccountSchemeName1Choice', 'xs:complexType')
# ('AccptncDtTm', 'xs:element')
# ('ActiveCurrencyAndAmount', 'xs:complexType')
# ('ActiveCurrencyAndAmount_SimpleType', 'xs:simpleType')
# ('ActiveCurrencyCode', 'xs:simpleType')
# ('ActiveOrHistoricCurrencyAndAmount', 'xs:complexType')
# ('ActiveOrHistoricCurrencyAndAmount_SimpleType', 'xs:simpleType')
# ('ActiveOrHistoricCurrencyCode', 'xs:simpleType')
# ('AddressType2Code', 'xs:simpleType')
# ('AddressType3Choice', 'xs:complexType')
# ('AddtlInf', 'xs:element')
# ('AddtlInf', 'xs:element')
# ('AddtlRmtInf', 'xs:element')
# ('AdjstmntAmtAndRsn', 'xs:element')
# ('AdjstmntAmtAndRsn', 'xs:element')
# ('AdmstnZone', 'xs:element')
# ('AdmstnZone', 'xs:element')
# ('Adr', 'xs:element')
# ('AdrLine', 'xs:element')
# ('AdrTp', 'xs:element')
# ('Agt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('AnyBIC', 'xs:element')
# ('AnyBICDec2014Identifier', 'xs:simpleType')
# ('Authrty', 'xs:element')
# ('Authstn', 'xs:element')
# ('BICFI', 'xs:element')
# ('BICFIDec2014Identifier', 'xs:simpleType')
# ('BaseOneRate', 'xs:simpleType')
# ('BatchBookingIndicator', 'xs:simpleType')
# ('BirthDt', 'xs:element')
# ('BldgNb', 'xs:element')
# ('BldgNm', 'xs:element')
# ('BranchAndFinancialInstitutionIdentification6', 'xs:complexType')
# ('BranchData3', 'xs:complexType')
# ('BrnchId', 'xs:element')
# ('BtchBookg', 'xs:element')
# ('CLSTm', 'xs:element')
# ('CashAccount38', 'xs:complexType')
# ('CashAccountType2Choice', 'xs:complexType')
# ('CategoryPurpose1Choice', 'xs:complexType')
# ('Ccy', 'xs:attribute')
# {'@name': 'Ccy', '@type': 'ActiveCurrencyCode', '@use': 'required'}
# ('Ccy', 'xs:attribute')
# {'@name': 'Ccy', '@type': 'ActiveOrHistoricCurrencyCode', '@use': 'required'}
# ('Ccy', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdtDbtInd', 'xs:element')
# ('CdtDtTm', 'xs:element')
# ('CdtNoteAmt', 'xs:element')
# ('CdtNoteAmt', 'xs:element')
# ('CdtTrfTxInf', 'xs:element')
# ('Cdtr', 'xs:element')
# ('Cdtr', 'xs:element')
# ('Cdtr', 'xs:element')
# ('CdtrAcct', 'xs:element')
# ('CdtrAgt', 'xs:element')
# ('CdtrAgtAcct', 'xs:element')
# ('CdtrRefInf', 'xs:element')
# ('CertId', 'xs:element')
# ('ChanlTp', 'xs:element')
# ('ChargeBearerType1Code', 'xs:simpleType')
# ('Charges7', 'xs:complexType')
# ('ChrgBr', 'xs:element')
# ('ChrgsInf', 'xs:element')
# ('CityOfBirth', 'xs:element')
# ('ClearingChannel2Code', 'xs:simpleType')
# ('ClearingSystemIdentification2Choice', 'xs:complexType')
# ('ClearingSystemIdentification3Choice', 'xs:complexType')
# ('ClearingSystemMemberIdentification2', 'xs:complexType')
# ('ClrChanl', 'xs:element')
# ('ClrSys', 'xs:element')
# ('ClrSysId', 'xs:element')
# ('ClrSysMmbId', 'xs:element')
# ('ClrSysRef', 'xs:element')
# ('Clssfctn', 'xs:element')
# ('CntPerPrd', 'xs:element')
# ('Contact4', 'xs:complexType')
# ('CountryCode', 'xs:simpleType')
# ('CreDtTm', 'xs:element')
# ('CreditDebitCode', 'xs:simpleType')
# ('CreditTransferMandateData1', 'xs:complexType')
# ('CreditTransferTransaction43', 'xs:complexType')
# ('CreditorReferenceInformation2', 'xs:complexType')
# ('CreditorReferenceType1Choice', 'xs:complexType')
# ('CreditorReferenceType2', 'xs:complexType')
# ('CtctDtls', 'xs:element')
# ('Ctgy', 'xs:element')
# ('CtgyDtls', 'xs:element')
# ('CtgyPurp', 'xs:element')
# ('CtgyPurp', 'xs:element')
# ('CtrlSum', 'xs:element')
# ('Ctry', 'xs:element')
# ('Ctry', 'xs:element')
# ('Ctry', 'xs:element')
# ('CtryOfBirth', 'xs:element')
# ('CtryOfRes', 'xs:element')
# ('CtrySubDvsn', 'xs:element')
# ('DateAndPlaceOfBirth1', 'xs:complexType')
# ('DatePeriod2', 'xs:complexType')
# ('DbtCdtRptgInd', 'xs:element')
# ('DbtDtTm', 'xs:element')
# ('Dbtr', 'xs:element')
# ('Dbtr', 'xs:element')
# ('Dbtr', 'xs:element')
# ('DbtrAcct', 'xs:element')
# ('DbtrAgt', 'xs:element')
# ('DbtrAgtAcct', 'xs:element')
# ('DbtrSts', 'xs:element')
# ('DecimalNumber', 'xs:simpleType')
# ('Dept', 'xs:element')
# ('Dept', 'xs:element')
# ('Desc', 'xs:element')
# ('DiscountAmountAndType1', 'xs:complexType')
# ('DiscountAmountType1Choice', 'xs:complexType')
# ('Document', 'xs:complexType')
# ('Document', 'xs:element')
# ('DocumentAdjustment1', 'xs:complexType')
# ('DocumentLineIdentification1', 'xs:complexType')
# ('DocumentLineInformation1', 'xs:complexType')
# ('DocumentLineType1', 'xs:complexType')
# ('DocumentLineType1Choice', 'xs:complexType')
# ('DocumentType3Code', 'xs:simpleType')
# ('DocumentType6Code', 'xs:simpleType')
# ('DscntApldAmt', 'xs:element')
# ('DscntApldAmt', 'xs:element')
# ('DstrctNm', 'xs:element')
# ('Dt', 'xs:element')
# ('Dt', 'xs:element')
# ('Dt', 'xs:element')
# ('Dt', 'xs:element')
# ('DtAndPlcOfBirth', 'xs:element')
# ('DtOfSgntr', 'xs:element')
# ('DtOfVrfctn', 'xs:element')
# ('Dtls', 'xs:element')
# ('Dtls', 'xs:element')
# ('DuePyblAmt', 'xs:element')
# ('DuePyblAmt', 'xs:element')
# ('ElctrncAdr', 'xs:element')
# ('ElctrncSgntr', 'xs:element')
# ('EmailAdr', 'xs:element')
# ('EmailPurp', 'xs:element')
# ('EndToEndId', 'xs:element')
# ('Envlp', 'xs:element')
# ('Exact2NumericText', 'xs:simpleType')
# ('Exact4AlphaNumericText', 'xs:simpleType')
# ('ExternalAccountIdentification1Code', 'xs:simpleType')
# ('ExternalCashAccountType1Code', 'xs:simpleType')
# ('ExternalCashClearingSystem1Code', 'xs:simpleType')
# ('ExternalCategoryPurpose1Code', 'xs:simpleType')
# ('ExternalClearingSystemIdentification1Code', 'xs:simpleType')
# ('ExternalCreditorAgentInstruction1Code', 'xs:simpleType')
# ('ExternalDiscountAmountType1Code', 'xs:simpleType')
# ('ExternalDocumentLineType1Code', 'xs:simpleType')
# ('ExternalFinancialInstitutionIdentification1Code', 'xs:simpleType')
# ('ExternalGarnishmentType1Code', 'xs:simpleType')
# ('ExternalLocalInstrument1Code', 'xs:simpleType')
# ('ExternalMandateSetupReason1Code', 'xs:simpleType')
# ('ExternalOrganisationIdentification1Code', 'xs:simpleType')
# ('ExternalPersonIdentification1Code', 'xs:simpleType')
# ('ExternalProxyAccountType1Code', 'xs:simpleType')
# ('ExternalPurpose1Code', 'xs:simpleType')
# ('ExternalServiceLevel1Code', 'xs:simpleType')
# ('ExternalTaxAmountType1Code', 'xs:simpleType')
# ('FIToFICstmrCdtTrf', 'xs:element')
# ('FIToFICustomerCreditTransferV09', 'xs:complexType')
# ('FaxNb', 'xs:element')
# ('FinInstnId', 'xs:element')
# ('FinancialIdentificationSchemeName1Choice', 'xs:complexType')
# ('FinancialInstitutionIdentification18', 'xs:complexType')
# ('Flr', 'xs:element')
# ('FmlyMdclInsrncInd', 'xs:element')
# ('FnlPmtDt', 'xs:element')
# ('FrDt', 'xs:element')
# ('FrTm', 'xs:element')
# ('FrToDt', 'xs:element')
# ('Frequency36Choice', 'xs:complexType')
# ('Frequency6Code', 'xs:simpleType')
# ('FrequencyAndMoment1', 'xs:complexType')
# ('FrequencyPeriod1', 'xs:complexType')
# ('FrmsCd', 'xs:element')
# ('Frqcy', 'xs:element')
# ('FrstPmtDt', 'xs:element')
# ('Garnishment3', 'xs:complexType')
# ('GarnishmentType1', 'xs:complexType')
# ('GarnishmentType1Choice', 'xs:complexType')
# ('GenericAccountIdentification1', 'xs:complexType')
# ('GenericFinancialIdentification1', 'xs:complexType')
# ('GenericIdentification30', 'xs:complexType')
# ('GenericOrganisationIdentification1', 'xs:complexType')
# ('GenericPersonIdentification1', 'xs:complexType')
# ('Grnshee', 'xs:element')
# ('GrnshmtAdmstr', 'xs:element')
# ('GrnshmtRmt', 'xs:element')
# ('GroupHeader93', 'xs:complexType')
# ('GrpHdr', 'xs:element')
# ('IBAN', 'xs:element')
# ('IBAN2007Identifier', 'xs:simpleType')
# ('ISODate', 'xs:simpleType')
# ('ISODateTime', 'xs:simpleType')
# ('ISOTime', 'xs:simpleType')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Inf', 'xs:element')
# ('InitgPty', 'xs:element')
# ('InstdAgt', 'xs:element')
# ('InstdAgt', 'xs:element')
# ('InstdAmt', 'xs:element')
# ('InstdRmbrsmntAgt', 'xs:element')
# ('InstdRmbrsmntAgtAcct', 'xs:element')
# ('InstgAgt', 'xs:element')
# ('InstgAgt', 'xs:element')
# ('InstgRmbrsmntAgt', 'xs:element')
# ('InstgRmbrsmntAgtAcct', 'xs:element')
# ('InstrForCdtrAgt', 'xs:element')
# ('InstrForNxtAgt', 'xs:element')
# ('InstrId', 'xs:element')
# ('InstrInf', 'xs:element')
# ('InstrInf', 'xs:element')
# ('InstrPrty', 'xs:element')
# ('Instruction4Code', 'xs:simpleType')
# ('InstructionForCreditorAgent3', 'xs:complexType')
# ('InstructionForNextAgent1', 'xs:complexType')
# ('IntrBkSttlmAmt', 'xs:element')
# ('IntrBkSttlmDt', 'xs:element')
# ('IntrBkSttlmDt', 'xs:element')
# ('IntrmyAgt1', 'xs:element')
# ('IntrmyAgt1Acct', 'xs:element')
# ('IntrmyAgt2', 'xs:element')
# ('IntrmyAgt2Acct', 'xs:element')
# ('IntrmyAgt3', 'xs:element')
# ('IntrmyAgt3Acct', 'xs:element')
# ('Invcee', 'xs:element')
# ('Invcr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('JobTitl', 'xs:element')
# ('LEI', 'xs:element')
# ('LEI', 'xs:element')
# ('LEI', 'xs:element')
# ('LEIIdentifier', 'xs:simpleType')
# ('LclInstrm', 'xs:element')
# ('LclInstrm', 'xs:element')
# ('LineDtls', 'xs:element')
# ('LocalInstrument2Choice', 'xs:complexType')
# ('MandateClassification1Choice', 'xs:complexType')
# ('MandateClassification1Code', 'xs:simpleType')
# ('MandateSetupReason1Choice', 'xs:complexType')
# ('MandateTypeInformation2', 'xs:complexType')
# ('Max10KBinary', 'xs:simpleType')
# ('Max10Text', 'xs:simpleType')
# ('Max128Text', 'xs:simpleType')
# ('Max140Text', 'xs:simpleType')
# ('Max15NumericText', 'xs:simpleType')
# ('Max16Text', 'xs:simpleType')
# ('Max2048Text', 'xs:simpleType')
# ('Max34Text', 'xs:simpleType')
# ('Max350Text', 'xs:simpleType')
# ('Max35Text', 'xs:simpleType')
# ('Max4Text', 'xs:simpleType')
# ('Max70Text', 'xs:simpleType')
# ('MmbId', 'xs:element')
# ('MndtId', 'xs:element')
# ('MndtRltdInf', 'xs:element')
# ('MobNb', 'xs:element')
# ('MplyeeTermntnInd', 'xs:element')
# ('MsgId', 'xs:element')
# ('Mtd', 'xs:element')
# ('Mtd', 'xs:element')
# ('Mtd', 'xs:element')
# ('NameAndAddress16', 'xs:complexType')
# ('NamePrefix2Code', 'xs:simpleType')
# ('Nb', 'xs:element')
# ('Nb', 'xs:element')
# ('NbOfTxs', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('NmPrfx', 'xs:element')
# ('Number', 'xs:simpleType')
# ('OrgId', 'xs:element')
# ('OrganisationIdentification29', 'xs:complexType')
# ('OrganisationIdentificationSchemeName1Choice', 'xs:complexType')
# ('OtherContact1', 'xs:complexType')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Party38Choice', 'xs:complexType')
# ('PartyIdentification135', 'xs:complexType')
# ('PaymentIdentification13', 'xs:complexType')
# ('PaymentTypeInformation28', 'xs:complexType')
# ('PercentageRate', 'xs:simpleType')
# ('PersonIdentification13', 'xs:complexType')
# ('PersonIdentificationSchemeName1Choice', 'xs:complexType')
# ('PhneNb', 'xs:element')
# ('PhoneNumber', 'xs:simpleType')
# ('PlcAndNm', 'xs:element')
# ('PmtId', 'xs:element')
# ('PmtTpInf', 'xs:element')
# ('PmtTpInf', 'xs:element')
# ('PoolgAdjstmntDt', 'xs:element')
# ('PostalAddress24', 'xs:complexType')
# ('Prd', 'xs:element')
# ('Prd', 'xs:element')
# ('Prd', 'xs:element')
# ('PreferredContactMethod1Code', 'xs:simpleType')
# ('PrefrdMtd', 'xs:element')
# ('Priority2Code', 'xs:simpleType')
# ('Priority3Code', 'xs:simpleType')
# ('ProxyAccountIdentification1', 'xs:complexType')
# ('ProxyAccountType1Choice', 'xs:complexType')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('PrvcOfBirth', 'xs:element')
# ('PrvsInstgAgt1', 'xs:element')
# ('PrvsInstgAgt1Acct', 'xs:element')
# ('PrvsInstgAgt2', 'xs:element')
# ('PrvsInstgAgt2Acct', 'xs:element')
# ('PrvsInstgAgt3', 'xs:element')
# ('PrvsInstgAgt3Acct', 'xs:element')
# ('PrvtId', 'xs:element')
# ('Prxy', 'xs:element')
# ('PstBx', 'xs:element')
# ('PstCd', 'xs:element')
# ('PstlAdr', 'xs:element')
# ('PstlAdr', 'xs:element')
# ('PstlAdr', 'xs:element')
# ('PstlAdr', 'xs:element')
# ('PtInTm', 'xs:element')
# ('PtInTm', 'xs:element')
# ('Purp', 'xs:element')
# ('Purpose2Choice', 'xs:complexType')
# ('Rate', 'xs:element')
# ('Rcrd', 'xs:element')
# ('Rcrd', 'xs:element')
# ('Ref', 'xs:element')
# ('RefNb', 'xs:element')
# ('RefNb', 'xs:element')
# ('RefNb', 'xs:element')
# ('ReferredDocumentInformation7', 'xs:complexType')
# ('ReferredDocumentType3Choice', 'xs:complexType')
# ('ReferredDocumentType4', 'xs:complexType')
# ('RegnId', 'xs:element')
# ('RegnId', 'xs:element')
# ('RegulatoryAuthority2', 'xs:complexType')
# ('RegulatoryReporting3', 'xs:complexType')
# ('RegulatoryReportingType1Code', 'xs:simpleType')
# ('RemittanceAmount2', 'xs:complexType')
# ('RemittanceAmount3', 'xs:complexType')
# ('RemittanceInformation16', 'xs:complexType')
# ('RemittanceLocation7', 'xs:complexType')
# ('RemittanceLocationData1', 'xs:complexType')
# ('RemittanceLocationMethod2Code', 'xs:simpleType')
# ('RfrdDocAmt', 'xs:element')
# ('RfrdDocInf', 'xs:element')
# ('RgltryRptg', 'xs:element')
# ('RjctTm', 'xs:element')
# ('RltdDt', 'xs:element')
# ('RltdDt', 'xs:element')
# ('RltdRmtInf', 'xs:element')
# ('RmtId', 'xs:element')
# ('RmtInf', 'xs:element')
# ('RmtLctnDtls', 'xs:element')
# ('RmtdAmt', 'xs:element')
# ('RmtdAmt', 'xs:element')
# ('RmtdAmt', 'xs:element')
# ('Room', 'xs:element')
# ('Rsn', 'xs:element')
# ('Rsn', 'xs:element')
# ('Rspnsblty', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SeqNb', 'xs:element')
# ('SeqNb', 'xs:element')
# ('ServiceLevel8Choice', 'xs:complexType')
# ('SettlementDateTimeIndication1', 'xs:complexType')
# ('SettlementInstruction7', 'xs:complexType')
# ('SettlementMethod1Code', 'xs:simpleType')
# ('SettlementTimeRequest2', 'xs:complexType')
# ('SplmtryData', 'xs:element')
# ('SplmtryData', 'xs:element')
# ('Strd', 'xs:element')
# ('StrtNm', 'xs:element')
# ('StructuredRegulatoryReporting3', 'xs:complexType')
# ('StructuredRemittanceInformation16', 'xs:complexType')
# ('SttlmAcct', 'xs:element')
# ('SttlmInf', 'xs:element')
# ('SttlmMtd', 'xs:element')
# ('SttlmPrty', 'xs:element')
# ('SttlmTmIndctn', 'xs:element')
# ('SttlmTmReq', 'xs:element')
# ('SubDept', 'xs:element')
# ('SupplementaryData1', 'xs:complexType')
# ('SupplementaryDataEnvelope1', 'xs:complexType')
# ('SvcLvl', 'xs:element')
# ('SvcLvl', 'xs:element')
# ('Tax', 'xs:element')
# ('TaxAmount2', 'xs:complexType')
# ('TaxAmountAndType1', 'xs:complexType')
# ('TaxAmountType1Choice', 'xs:complexType')
# ('TaxAmt', 'xs:element')
# ('TaxAmt', 'xs:element')
# ('TaxAmt', 'xs:element')
# ('TaxAuthorisation1', 'xs:complexType')
# ('TaxId', 'xs:element')
# ('TaxId', 'xs:element')
# ('TaxInformation7', 'xs:complexType')
# ('TaxInformation8', 'xs:complexType')
# ('TaxParty1', 'xs:complexType')
# ('TaxParty2', 'xs:complexType')
# ('TaxPeriod2', 'xs:complexType')
# ('TaxRecord2', 'xs:complexType')
# ('TaxRecordDetails2', 'xs:complexType')
# ('TaxRecordPeriod1Code', 'xs:simpleType')
# ('TaxRmt', 'xs:element')
# ('TaxTp', 'xs:element')
# ('TaxTp', 'xs:element')
# ('TaxblBaseAmt', 'xs:element')
# ('ThrdRmbrsmntAgt', 'xs:element')
# ('ThrdRmbrsmntAgtAcct', 'xs:element')
# ('TillTm', 'xs:element')
# ('Titl', 'xs:element')
# ('ToDt', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('TrueFalseIndicator', 'xs:simpleType')
# ('TtlAmt', 'xs:element')
# ('TtlIntrBkSttlmAmt', 'xs:element')
# ('TtlTaxAmt', 'xs:element')
# ('TtlTaxAmt', 'xs:element')
# ('TtlTaxblBaseAmt', 'xs:element')
# ('TtlTaxblBaseAmt', 'xs:element')
# ('TwnLctnNm', 'xs:element')
# ('TwnNm', 'xs:element')
# ('TxId', 'xs:element')
# ('UETR', 'xs:element')
# ('UUIDv4Identifier', 'xs:simpleType')
# ('UltmtCdtr', 'xs:element')
# ('UltmtDbtr', 'xs:element')
# ('UltmtDbtr', 'xs:element')
# ('Ustrd', 'xs:element')
# ('XchgRate', 'xs:element')
# ('Yr', 'xs:element')
# ('xs:NOTATION', 'xs:primitiveType')
# ('xs:QName', 'xs:primitiveType')
# ('xs:anyURI', 'xs:primitiveType')
# ('xs:base64Binary', 'xs:primitiveType')
# ('xs:boolean', 'xs:primitiveType')
# ('xs:byte', 'xs:primitiveType')
# ('xs:date', 'xs:primitiveType')
# ('xs:dateTime', 'xs:primitiveType')
# ('xs:decimal', 'xs:primitiveType')
# ('xs:double', 'xs:primitiveType')
# ('xs:duration', 'xs:primitiveType')
# ('xs:float', 'xs:primitiveType')
# ('xs:gDay', 'xs:primitiveType')
# ('xs:gMonth', 'xs:primitiveType')
# ('xs:gMonthDay', 'xs:primitiveType')
# ('xs:gYear', 'xs:primitiveType')
# ('xs:gYearMonth', 'xs:primitiveType')
# ('xs:hexBinary', 'xs:primitiveType')
# ('xs:int', 'xs:primitiveType')
# ('xs:integer', 'xs:primitiveType')
# ('xs:negativeInteger', 'xs:primitiveType')
# ('xs:nonNegativeInteger', 'xs:primitiveType')
# ('xs:nonPositiveInteger', 'xs:primitiveType')
# ('xs:positiveInteger', 'xs:primitiveType')
# ('xs:short', 'xs:primitiveType')
# ('xs:string', 'xs:primitiveType')
# ('xs:time', 'xs:primitiveType')
# ('xs:unsignedByte', 'xs:primitiveType')
# ('xs:unsignedInt', 'xs:primitiveType')
# ('xs:unsignedLong', 'xs:primitiveType')
# ('xs:unsignedShort', 'xs:primitiveType')
# 100
# Iteration  3
# ('AccountIdentification4Choice', 'xs:complexType')
# ('AccountSchemeName1Choice', 'xs:complexType')
# ('AccptncDtTm', 'xs:element')
# ('ActiveCurrencyAndAmount', 'xs:complexType')
# ('ActiveCurrencyAndAmount_SimpleType', 'xs:simpleType')
# ('ActiveCurrencyCode', 'xs:simpleType')
# ('ActiveOrHistoricCurrencyAndAmount', 'xs:complexType')
# ('ActiveOrHistoricCurrencyAndAmount_SimpleType', 'xs:simpleType')
# ('ActiveOrHistoricCurrencyCode', 'xs:simpleType')
# ('AddressType2Code', 'xs:simpleType')
# ('AddressType3Choice', 'xs:complexType')
# ('AddtlInf', 'xs:element')
# ('AddtlInf', 'xs:element')
# ('AddtlRmtInf', 'xs:element')
# ('AdjstmntAmtAndRsn', 'xs:element')
# ('AdjstmntAmtAndRsn', 'xs:element')
# ('AdmstnZone', 'xs:element')
# ('AdmstnZone', 'xs:element')
# ('Adr', 'xs:element')
# ('AdrLine', 'xs:element')
# ('AdrTp', 'xs:element')
# ('Agt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('Amt', 'xs:element')
# ('AnyBIC', 'xs:element')
# ('AnyBICDec2014Identifier', 'xs:simpleType')
# ('Authrty', 'xs:element')
# ('Authstn', 'xs:element')
# ('BICFI', 'xs:element')
# ('BICFIDec2014Identifier', 'xs:simpleType')
# ('BaseOneRate', 'xs:simpleType')
# ('BatchBookingIndicator', 'xs:simpleType')
# ('BirthDt', 'xs:element')
# ('BldgNb', 'xs:element')
# ('BldgNm', 'xs:element')
# ('BranchAndFinancialInstitutionIdentification6', 'xs:complexType')
# ('BranchData3', 'xs:complexType')
# ('BrnchId', 'xs:element')
# ('BtchBookg', 'xs:element')
# ('CLSTm', 'xs:element')
# ('CashAccount38', 'xs:complexType')
# ('CashAccountType2Choice', 'xs:complexType')
# ('CategoryPurpose1Choice', 'xs:complexType')
# ('Ccy', 'xs:attribute')
# {'@name': 'Ccy', '@type': 'ActiveCurrencyCode', '@use': 'required'}
# ('Ccy', 'xs:attribute')
# {'@name': 'Ccy', '@type': 'ActiveOrHistoricCurrencyCode', '@use': 'required'}
# ('Ccy', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdtDbtInd', 'xs:element')
# ('CdtDtTm', 'xs:element')
# ('CdtNoteAmt', 'xs:element')
# ('CdtNoteAmt', 'xs:element')
# ('CdtTrfTxInf', 'xs:element')
# ('Cdtr', 'xs:element')
# ('Cdtr', 'xs:element')
# ('Cdtr', 'xs:element')
# ('CdtrAcct', 'xs:element')
# ('CdtrAgt', 'xs:element')
# ('CdtrAgtAcct', 'xs:element')
# ('CdtrRefInf', 'xs:element')
# ('CertId', 'xs:element')
# ('ChanlTp', 'xs:element')
# ('ChargeBearerType1Code', 'xs:simpleType')
# ('Charges7', 'xs:complexType')
# ('ChrgBr', 'xs:element')
# ('ChrgsInf', 'xs:element')
# ('CityOfBirth', 'xs:element')
# ('ClearingChannel2Code', 'xs:simpleType')
# ('ClearingSystemIdentification2Choice', 'xs:complexType')
# ('ClearingSystemIdentification3Choice', 'xs:complexType')
# ('ClearingSystemMemberIdentification2', 'xs:complexType')
# ('ClrChanl', 'xs:element')
# ('ClrSys', 'xs:element')
# ('ClrSysId', 'xs:element')
# ('ClrSysMmbId', 'xs:element')
# ('ClrSysRef', 'xs:element')
# ('Clssfctn', 'xs:element')
# ('CntPerPrd', 'xs:element')
# ('Contact4', 'xs:complexType')
# ('CountryCode', 'xs:simpleType')
# ('CreDtTm', 'xs:element')
# ('CreditDebitCode', 'xs:simpleType')
# ('CreditTransferMandateData1', 'xs:complexType')
# ('CreditTransferTransaction43', 'xs:complexType')
# ('CreditorReferenceInformation2', 'xs:complexType')
# ('CreditorReferenceType1Choice', 'xs:complexType')
# ('CreditorReferenceType2', 'xs:complexType')
# ('CtctDtls', 'xs:element')
# ('Ctgy', 'xs:element')
# ('CtgyDtls', 'xs:element')
# ('CtgyPurp', 'xs:element')
# ('CtgyPurp', 'xs:element')
# ('CtrlSum', 'xs:element')
# ('Ctry', 'xs:element')
# ('Ctry', 'xs:element')
# ('Ctry', 'xs:element')
# ('CtryOfBirth', 'xs:element')
# ('CtryOfRes', 'xs:element')
# ('CtrySubDvsn', 'xs:element')
# ('DateAndPlaceOfBirth1', 'xs:complexType')
# ('DatePeriod2', 'xs:complexType')
# ('DbtCdtRptgInd', 'xs:element')
# ('DbtDtTm', 'xs:element')
# ('Dbtr', 'xs:element')
# ('Dbtr', 'xs:element')
# ('Dbtr', 'xs:element')
# ('DbtrAcct', 'xs:element')
# ('DbtrAgt', 'xs:element')
# ('DbtrAgtAcct', 'xs:element')
# ('DbtrSts', 'xs:element')
# ('DecimalNumber', 'xs:simpleType')
# ('Dept', 'xs:element')
# ('Dept', 'xs:element')
# ('Desc', 'xs:element')
# ('DiscountAmountAndType1', 'xs:complexType')
# ('DiscountAmountType1Choice', 'xs:complexType')
# ('Document', 'xs:complexType')
# ('Document', 'xs:element')
# ('DocumentAdjustment1', 'xs:complexType')
# ('DocumentLineIdentification1', 'xs:complexType')
# ('DocumentLineInformation1', 'xs:complexType')
# ('DocumentLineType1', 'xs:complexType')
# ('DocumentLineType1Choice', 'xs:complexType')
# ('DocumentType3Code', 'xs:simpleType')
# ('DocumentType6Code', 'xs:simpleType')
# ('DscntApldAmt', 'xs:element')
# ('DscntApldAmt', 'xs:element')
# ('DstrctNm', 'xs:element')
# ('Dt', 'xs:element')
# ('Dt', 'xs:element')
# ('Dt', 'xs:element')
# ('Dt', 'xs:element')
# ('DtAndPlcOfBirth', 'xs:element')
# ('DtOfSgntr', 'xs:element')
# ('DtOfVrfctn', 'xs:element')
# ('Dtls', 'xs:element')
# ('Dtls', 'xs:element')
# ('DuePyblAmt', 'xs:element')
# ('DuePyblAmt', 'xs:element')
# ('ElctrncAdr', 'xs:element')
# ('ElctrncSgntr', 'xs:element')
# ('EmailAdr', 'xs:element')
# ('EmailPurp', 'xs:element')
# ('EndToEndId', 'xs:element')
# ('Envlp', 'xs:element')
# ('Exact2NumericText', 'xs:simpleType')
# ('Exact4AlphaNumericText', 'xs:simpleType')
# ('ExternalAccountIdentification1Code', 'xs:simpleType')
# ('ExternalCashAccountType1Code', 'xs:simpleType')
# ('ExternalCashClearingSystem1Code', 'xs:simpleType')
# ('ExternalCategoryPurpose1Code', 'xs:simpleType')
# ('ExternalClearingSystemIdentification1Code', 'xs:simpleType')
# ('ExternalCreditorAgentInstruction1Code', 'xs:simpleType')
# ('ExternalDiscountAmountType1Code', 'xs:simpleType')
# ('ExternalDocumentLineType1Code', 'xs:simpleType')
# ('ExternalFinancialInstitutionIdentification1Code', 'xs:simpleType')
# ('ExternalGarnishmentType1Code', 'xs:simpleType')
# ('ExternalLocalInstrument1Code', 'xs:simpleType')
# ('ExternalMandateSetupReason1Code', 'xs:simpleType')
# ('ExternalOrganisationIdentification1Code', 'xs:simpleType')
# ('ExternalPersonIdentification1Code', 'xs:simpleType')
# ('ExternalProxyAccountType1Code', 'xs:simpleType')
# ('ExternalPurpose1Code', 'xs:simpleType')
# ('ExternalServiceLevel1Code', 'xs:simpleType')
# ('ExternalTaxAmountType1Code', 'xs:simpleType')
# ('FIToFICstmrCdtTrf', 'xs:element')
# ('FIToFICustomerCreditTransferV09', 'xs:complexType')
# ('FaxNb', 'xs:element')
# ('FinInstnId', 'xs:element')
# ('FinancialIdentificationSchemeName1Choice', 'xs:complexType')
# ('FinancialInstitutionIdentification18', 'xs:complexType')
# ('Flr', 'xs:element')
# ('FmlyMdclInsrncInd', 'xs:element')
# ('FnlPmtDt', 'xs:element')
# ('FrDt', 'xs:element')
# ('FrTm', 'xs:element')
# ('FrToDt', 'xs:element')
# ('Frequency36Choice', 'xs:complexType')
# ('Frequency6Code', 'xs:simpleType')
# ('FrequencyAndMoment1', 'xs:complexType')
# ('FrequencyPeriod1', 'xs:complexType')
# ('FrmsCd', 'xs:element')
# ('Frqcy', 'xs:element')
# ('FrstPmtDt', 'xs:element')
# ('Garnishment3', 'xs:complexType')
# ('GarnishmentType1', 'xs:complexType')
# ('GarnishmentType1Choice', 'xs:complexType')
# ('GenericAccountIdentification1', 'xs:complexType')
# ('GenericFinancialIdentification1', 'xs:complexType')
# ('GenericIdentification30', 'xs:complexType')
# ('GenericOrganisationIdentification1', 'xs:complexType')
# ('GenericPersonIdentification1', 'xs:complexType')
# ('Grnshee', 'xs:element')
# ('GrnshmtAdmstr', 'xs:element')
# ('GrnshmtRmt', 'xs:element')
# ('GroupHeader93', 'xs:complexType')
# ('GrpHdr', 'xs:element')
# ('IBAN', 'xs:element')
# ('IBAN2007Identifier', 'xs:simpleType')
# ('ISODate', 'xs:simpleType')
# ('ISODateTime', 'xs:simpleType')
# ('ISOTime', 'xs:simpleType')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Inf', 'xs:element')
# ('InitgPty', 'xs:element')
# ('InstdAgt', 'xs:element')
# ('InstdAgt', 'xs:element')
# ('InstdAmt', 'xs:element')
# ('InstdRmbrsmntAgt', 'xs:element')
# ('InstdRmbrsmntAgtAcct', 'xs:element')
# ('InstgAgt', 'xs:element')
# ('InstgAgt', 'xs:element')
# ('InstgRmbrsmntAgt', 'xs:element')
# ('InstgRmbrsmntAgtAcct', 'xs:element')
# ('InstrForCdtrAgt', 'xs:element')
# ('InstrForNxtAgt', 'xs:element')
# ('InstrId', 'xs:element')
# ('InstrInf', 'xs:element')
# ('InstrInf', 'xs:element')
# ('InstrPrty', 'xs:element')
# ('Instruction4Code', 'xs:simpleType')
# ('InstructionForCreditorAgent3', 'xs:complexType')
# ('InstructionForNextAgent1', 'xs:complexType')
# ('IntrBkSttlmAmt', 'xs:element')
# ('IntrBkSttlmDt', 'xs:element')
# ('IntrBkSttlmDt', 'xs:element')
# ('IntrmyAgt1', 'xs:element')
# ('IntrmyAgt1Acct', 'xs:element')
# ('IntrmyAgt2', 'xs:element')
# ('IntrmyAgt2Acct', 'xs:element')
# ('IntrmyAgt3', 'xs:element')
# ('IntrmyAgt3Acct', 'xs:element')
# ('Invcee', 'xs:element')
# ('Invcr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('JobTitl', 'xs:element')
# ('LEI', 'xs:element')
# ('LEI', 'xs:element')
# ('LEI', 'xs:element')
# ('LEIIdentifier', 'xs:simpleType')
# ('LclInstrm', 'xs:element')
# ('LclInstrm', 'xs:element')
# ('LineDtls', 'xs:element')
# ('LocalInstrument2Choice', 'xs:complexType')
# ('MandateClassification1Choice', 'xs:complexType')
# ('MandateClassification1Code', 'xs:simpleType')
# ('MandateSetupReason1Choice', 'xs:complexType')
# ('MandateTypeInformation2', 'xs:complexType')
# ('Max10KBinary', 'xs:simpleType')
# ('Max10Text', 'xs:simpleType')
# ('Max128Text', 'xs:simpleType')
# ('Max140Text', 'xs:simpleType')
# ('Max15NumericText', 'xs:simpleType')
# ('Max16Text', 'xs:simpleType')
# ('Max2048Text', 'xs:simpleType')
# ('Max34Text', 'xs:simpleType')
# ('Max350Text', 'xs:simpleType')
# ('Max35Text', 'xs:simpleType')
# ('Max4Text', 'xs:simpleType')
# ('Max70Text', 'xs:simpleType')
# ('MmbId', 'xs:element')
# ('MndtId', 'xs:element')
# ('MndtRltdInf', 'xs:element')
# ('MobNb', 'xs:element')
# ('MplyeeTermntnInd', 'xs:element')
# ('MsgId', 'xs:element')
# ('Mtd', 'xs:element')
# ('Mtd', 'xs:element')
# ('Mtd', 'xs:element')
# ('NameAndAddress16', 'xs:complexType')
# ('NamePrefix2Code', 'xs:simpleType')
# ('Nb', 'xs:element')
# ('Nb', 'xs:element')
# ('NbOfTxs', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('NmPrfx', 'xs:element')
# ('Number', 'xs:simpleType')
# ('OrgId', 'xs:element')
# ('OrganisationIdentification29', 'xs:complexType')
# ('OrganisationIdentificationSchemeName1Choice', 'xs:complexType')
# ('OtherContact1', 'xs:complexType')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Party38Choice', 'xs:complexType')
# ('PartyIdentification135', 'xs:complexType')
# ('PaymentIdentification13', 'xs:complexType')
# ('PaymentTypeInformation28', 'xs:complexType')
# ('PercentageRate', 'xs:simpleType')
# ('PersonIdentification13', 'xs:complexType')
# ('PersonIdentificationSchemeName1Choice', 'xs:complexType')
# ('PhneNb', 'xs:element')
# ('PhoneNumber', 'xs:simpleType')
# ('PlcAndNm', 'xs:element')
# ('PmtId', 'xs:element')
# ('PmtTpInf', 'xs:element')
# ('PmtTpInf', 'xs:element')
# ('PoolgAdjstmntDt', 'xs:element')
# ('PostalAddress24', 'xs:complexType')
# ('Prd', 'xs:element')
# ('Prd', 'xs:element')
# ('Prd', 'xs:element')
# ('PreferredContactMethod1Code', 'xs:simpleType')
# ('PrefrdMtd', 'xs:element')
# ('Priority2Code', 'xs:simpleType')
# ('Priority3Code', 'xs:simpleType')
# ('ProxyAccountIdentification1', 'xs:complexType')
# ('ProxyAccountType1Choice', 'xs:complexType')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ...
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('Cd', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdOrPrtry', 'xs:element')
# ('CdtDbtInd', 'xs:element')
# ('CdtDtTm', 'xs:element')
# ('CdtNoteAmt', 'xs:element')
# ('CdtNoteAmt', 'xs:element')
# ('CdtTrfTxInf', 'xs:element')
# ('Cdtr', 'xs:element')
# ('Cdtr', 'xs:element')
# ('Cdtr', 'xs:element')
# ('CdtrAcct', 'xs:element')
# ('CdtrAgt', 'xs:element')
# ('CdtrAgtAcct', 'xs:element')
# ('CdtrRefInf', 'xs:element')
# ('CertId', 'xs:element')
# ('ChanlTp', 'xs:element')
# ('ChargeBearerType1Code', 'xs:simpleType')
# ('Charges7', 'xs:complexType')
# ('ChrgBr', 'xs:element')
# ('ChrgsInf', 'xs:element')
# ('CityOfBirth', 'xs:element')
# ('ClearingChannel2Code', 'xs:simpleType')
# ('ClearingSystemIdentification2Choice', 'xs:complexType')
# ('ClearingSystemIdentification3Choice', 'xs:complexType')
# ('ClearingSystemMemberIdentification2', 'xs:complexType')
# ('ClrChanl', 'xs:element')
# ('ClrSys', 'xs:element')
# ('ClrSysId', 'xs:element')
# ('ClrSysMmbId', 'xs:element')
# ('ClrSysRef', 'xs:element')
# ('Clssfctn', 'xs:element')
# ('CntPerPrd', 'xs:element')
# ('Contact4', 'xs:complexType')
# ('CountryCode', 'xs:simpleType')
# ('CreDtTm', 'xs:element')
# ('CreditDebitCode', 'xs:simpleType')
# ('CreditTransferMandateData1', 'xs:complexType')
# ('CreditTransferTransaction43', 'xs:complexType')
# ('CreditorReferenceInformation2', 'xs:complexType')
# ('CreditorReferenceType1Choice', 'xs:complexType')
# ('CreditorReferenceType2', 'xs:complexType')
# ('CtctDtls', 'xs:element')
# ('Ctgy', 'xs:element')
# ('CtgyDtls', 'xs:element')
# ('CtgyPurp', 'xs:element')
# ('CtgyPurp', 'xs:element')
# ('CtrlSum', 'xs:element')
# ('Ctry', 'xs:element')
# ('Ctry', 'xs:element')
# ('Ctry', 'xs:element')
# ('CtryOfBirth', 'xs:element')
# ('CtryOfRes', 'xs:element')
# ('CtrySubDvsn', 'xs:element')
# ('DateAndPlaceOfBirth1', 'xs:complexType')
# ('DatePeriod2', 'xs:complexType')
# ('DbtCdtRptgInd', 'xs:element')
# ('DbtDtTm', 'xs:element')
# ('Dbtr', 'xs:element')
# ('Dbtr', 'xs:element')
# ('Dbtr', 'xs:element')
# ('DbtrAcct', 'xs:element')
# ('DbtrAgt', 'xs:element')
# ('DbtrAgtAcct', 'xs:element')
# ('DbtrSts', 'xs:element')
# ('DecimalNumber', 'xs:simpleType')
# ('Dept', 'xs:element')
# ('Dept', 'xs:element')
# ('Desc', 'xs:element')
# ('DiscountAmountAndType1', 'xs:complexType')
# ('DiscountAmountType1Choice', 'xs:complexType')
# ('Document', 'xs:complexType')
# ('Document', 'xs:element')
# ('DocumentAdjustment1', 'xs:complexType')
# ('DocumentLineIdentification1', 'xs:complexType')
# ('DocumentLineInformation1', 'xs:complexType')
# ('DocumentLineType1', 'xs:complexType')
# ('DocumentLineType1Choice', 'xs:complexType')
# ('DocumentType3Code', 'xs:simpleType')
# ('DocumentType6Code', 'xs:simpleType')
# ('DscntApldAmt', 'xs:element')
# ('DscntApldAmt', 'xs:element')
# ('DstrctNm', 'xs:element')
# ('Dt', 'xs:element')
# ('Dt', 'xs:element')
# ('Dt', 'xs:element')
# ('Dt', 'xs:element')
# ('DtAndPlcOfBirth', 'xs:element')
# ('DtOfSgntr', 'xs:element')
# ('DtOfVrfctn', 'xs:element')
# ('Dtls', 'xs:element')
# ('Dtls', 'xs:element')
# ('DuePyblAmt', 'xs:element')
# ('DuePyblAmt', 'xs:element')
# ('ElctrncAdr', 'xs:element')
# ('ElctrncSgntr', 'xs:element')
# ('EmailAdr', 'xs:element')
# ('EmailPurp', 'xs:element')
# ('EndToEndId', 'xs:element')
# ('Envlp', 'xs:element')
# ('Exact2NumericText', 'xs:simpleType')
# ('Exact4AlphaNumericText', 'xs:simpleType')
# ('ExternalAccountIdentification1Code', 'xs:simpleType')
# ('ExternalCashAccountType1Code', 'xs:simpleType')
# ('ExternalCashClearingSystem1Code', 'xs:simpleType')
# ('ExternalCategoryPurpose1Code', 'xs:simpleType')
# ('ExternalClearingSystemIdentification1Code', 'xs:simpleType')
# ('ExternalCreditorAgentInstruction1Code', 'xs:simpleType')
# ('ExternalDiscountAmountType1Code', 'xs:simpleType')
# ('ExternalDocumentLineType1Code', 'xs:simpleType')
# ('ExternalFinancialInstitutionIdentification1Code', 'xs:simpleType')
# ('ExternalGarnishmentType1Code', 'xs:simpleType')
# ('ExternalLocalInstrument1Code', 'xs:simpleType')
# ('ExternalMandateSetupReason1Code', 'xs:simpleType')
# ('ExternalOrganisationIdentification1Code', 'xs:simpleType')
# ('ExternalPersonIdentification1Code', 'xs:simpleType')
# ('ExternalProxyAccountType1Code', 'xs:simpleType')
# ('ExternalPurpose1Code', 'xs:simpleType')
# ('ExternalServiceLevel1Code', 'xs:simpleType')
# ('ExternalTaxAmountType1Code', 'xs:simpleType')
# ('FIToFICstmrCdtTrf', 'xs:element')
# ('FIToFICustomerCreditTransferV09', 'xs:complexType')
# ('FaxNb', 'xs:element')
# ('FinInstnId', 'xs:element')
# ('FinancialIdentificationSchemeName1Choice', 'xs:complexType')
# ('FinancialInstitutionIdentification18', 'xs:complexType')
# ('Flr', 'xs:element')
# ('FmlyMdclInsrncInd', 'xs:element')
# ('FnlPmtDt', 'xs:element')
# ('FrDt', 'xs:element')
# ('FrTm', 'xs:element')
# ('FrToDt', 'xs:element')
# ('Frequency36Choice', 'xs:complexType')
# ('Frequency6Code', 'xs:simpleType')
# ('FrequencyAndMoment1', 'xs:complexType')
# ('FrequencyPeriod1', 'xs:complexType')
# ('FrmsCd', 'xs:element')
# ('Frqcy', 'xs:element')
# ('FrstPmtDt', 'xs:element')
# ('Garnishment3', 'xs:complexType')
# ('GarnishmentType1', 'xs:complexType')
# ('GarnishmentType1Choice', 'xs:complexType')
# ('GenericAccountIdentification1', 'xs:complexType')
# ('GenericFinancialIdentification1', 'xs:complexType')
# ('GenericIdentification30', 'xs:complexType')
# ('GenericOrganisationIdentification1', 'xs:complexType')
# ('GenericPersonIdentification1', 'xs:complexType')
# ('Grnshee', 'xs:element')
# ('GrnshmtAdmstr', 'xs:element')
# ('GrnshmtRmt', 'xs:element')
# ('GroupHeader93', 'xs:complexType')
# ('GrpHdr', 'xs:element')
# ('IBAN', 'xs:element')
# ('IBAN2007Identifier', 'xs:simpleType')
# ('ISODate', 'xs:simpleType')
# ('ISODateTime', 'xs:simpleType')
# ('ISOTime', 'xs:simpleType')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Id', 'xs:element')
# ('Inf', 'xs:element')
# ('InitgPty', 'xs:element')
# ('InstdAgt', 'xs:element')
# ('InstdAgt', 'xs:element')
# ('InstdAmt', 'xs:element')
# ('InstdRmbrsmntAgt', 'xs:element')
# ('InstdRmbrsmntAgtAcct', 'xs:element')
# ('InstgAgt', 'xs:element')
# ('InstgAgt', 'xs:element')
# ('InstgRmbrsmntAgt', 'xs:element')
# ('InstgRmbrsmntAgtAcct', 'xs:element')
# ('InstrForCdtrAgt', 'xs:element')
# ('InstrForNxtAgt', 'xs:element')
# ('InstrId', 'xs:element')
# ('InstrInf', 'xs:element')
# ('InstrInf', 'xs:element')
# ('InstrPrty', 'xs:element')
# ('Instruction4Code', 'xs:simpleType')
# ('InstructionForCreditorAgent3', 'xs:complexType')
# ('InstructionForNextAgent1', 'xs:complexType')
# ('IntrBkSttlmAmt', 'xs:element')
# ('IntrBkSttlmDt', 'xs:element')
# ('IntrBkSttlmDt', 'xs:element')
# ('IntrmyAgt1', 'xs:element')
# ('IntrmyAgt1Acct', 'xs:element')
# ('IntrmyAgt2', 'xs:element')
# ('IntrmyAgt2Acct', 'xs:element')
# ('IntrmyAgt3', 'xs:element')
# ('IntrmyAgt3Acct', 'xs:element')
# ('Invcee', 'xs:element')
# ('Invcr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('Issr', 'xs:element')
# ('JobTitl', 'xs:element')
# ('LEI', 'xs:element')
# ('LEI', 'xs:element')
# ('LEI', 'xs:element')
# ('LEIIdentifier', 'xs:simpleType')
# ('LclInstrm', 'xs:element')
# ('LclInstrm', 'xs:element')
# ('LineDtls', 'xs:element')
# ('LocalInstrument2Choice', 'xs:complexType')
# ('MandateClassification1Choice', 'xs:complexType')
# ('MandateClassification1Code', 'xs:simpleType')
# ('MandateSetupReason1Choice', 'xs:complexType')
# ('MandateTypeInformation2', 'xs:complexType')
# ('Max10KBinary', 'xs:simpleType')
# ('Max10Text', 'xs:simpleType')
# ('Max128Text', 'xs:simpleType')
# ('Max140Text', 'xs:simpleType')
# ('Max15NumericText', 'xs:simpleType')
# ('Max16Text', 'xs:simpleType')
# ('Max2048Text', 'xs:simpleType')
# ('Max34Text', 'xs:simpleType')
# ('Max350Text', 'xs:simpleType')
# ('Max35Text', 'xs:simpleType')
# ('Max4Text', 'xs:simpleType')
# ('Max70Text', 'xs:simpleType')
# ('MmbId', 'xs:element')
# ('MndtId', 'xs:element')
# ('MndtRltdInf', 'xs:element')
# ('MobNb', 'xs:element')
# ('MplyeeTermntnInd', 'xs:element')
# ('MsgId', 'xs:element')
# ('Mtd', 'xs:element')
# ('Mtd', 'xs:element')
# ('Mtd', 'xs:element')
# ('NameAndAddress16', 'xs:complexType')
# ('NamePrefix2Code', 'xs:simpleType')
# ('Nb', 'xs:element')
# ('Nb', 'xs:element')
# ('NbOfTxs', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('Nm', 'xs:element')
# ('NmPrfx', 'xs:element')
# ('Number', 'xs:simpleType')
# ('OrgId', 'xs:element')
# ('OrganisationIdentification29', 'xs:complexType')
# ('OrganisationIdentificationSchemeName1Choice', 'xs:complexType')
# ('OtherContact1', 'xs:complexType')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Othr', 'xs:element')
# ('Party38Choice', 'xs:complexType')
# ('PartyIdentification135', 'xs:complexType')
# ('PaymentIdentification13', 'xs:complexType')
# ('PaymentTypeInformation28', 'xs:complexType')
# ('PercentageRate', 'xs:simpleType')
# ('PersonIdentification13', 'xs:complexType')
# ('PersonIdentificationSchemeName1Choice', 'xs:complexType')
# ('PhneNb', 'xs:element')
# ('PhoneNumber', 'xs:simpleType')
# ('PlcAndNm', 'xs:element')
# ('PmtId', 'xs:element')
# ('PmtTpInf', 'xs:element')
# ('PmtTpInf', 'xs:element')
# ('PoolgAdjstmntDt', 'xs:element')
# ('PostalAddress24', 'xs:complexType')
# ('Prd', 'xs:element')
# ('Prd', 'xs:element')
# ('Prd', 'xs:element')
# ('PreferredContactMethod1Code', 'xs:simpleType')
# ('PrefrdMtd', 'xs:element')
# ('Priority2Code', 'xs:simpleType')
# ('Priority3Code', 'xs:simpleType')
# ('ProxyAccountIdentification1', 'xs:complexType')
# ('ProxyAccountType1Choice', 'xs:complexType')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('Prtry', 'xs:element')
# ('PrvcOfBirth', 'xs:element')
# ('PrvsInstgAgt1', 'xs:element')
# ('PrvsInstgAgt1Acct', 'xs:element')
# ('PrvsInstgAgt2', 'xs:element')
# ('PrvsInstgAgt2Acct', 'xs:element')
# ('PrvsInstgAgt3', 'xs:element')
# ('PrvsInstgAgt3Acct', 'xs:element')
# ('PrvtId', 'xs:element')
# ('Prxy', 'xs:element')
# ('PstBx', 'xs:element')
# ('PstCd', 'xs:element')
# ('PstlAdr', 'xs:element')
# ('PstlAdr', 'xs:element')
# ('PstlAdr', 'xs:element')
# ('PstlAdr', 'xs:element')
# ('PtInTm', 'xs:element')
# ('PtInTm', 'xs:element')
# ('Purp', 'xs:element')
# ('Purpose2Choice', 'xs:complexType')
# ('Rate', 'xs:element')
# ('Rcrd', 'xs:element')
# ('Rcrd', 'xs:element')
# ('Ref', 'xs:element')
# ('RefNb', 'xs:element')
# ('RefNb', 'xs:element')
# ('RefNb', 'xs:element')
# ('ReferredDocumentInformation7', 'xs:complexType')
# ('ReferredDocumentType3Choice', 'xs:complexType')
# ('ReferredDocumentType4', 'xs:complexType')
# ('RegnId', 'xs:element')
# ('RegnId', 'xs:element')
# ('RegulatoryAuthority2', 'xs:complexType')
# ('RegulatoryReporting3', 'xs:complexType')
# ('RegulatoryReportingType1Code', 'xs:simpleType')
# ('RemittanceAmount2', 'xs:complexType')
# ('RemittanceAmount3', 'xs:complexType')
# ('RemittanceInformation16', 'xs:complexType')
# ('RemittanceLocation7', 'xs:complexType')
# ('RemittanceLocationData1', 'xs:complexType')
# ('RemittanceLocationMethod2Code', 'xs:simpleType')
# ('RfrdDocAmt', 'xs:element')
# ('RfrdDocInf', 'xs:element')
# ('RgltryRptg', 'xs:element')
# ('RjctTm', 'xs:element')
# ('RltdDt', 'xs:element')
# ('RltdDt', 'xs:element')
# ('RltdRmtInf', 'xs:element')
# ('RmtId', 'xs:element')
# ('RmtInf', 'xs:element')
# ('RmtLctnDtls', 'xs:element')
# ('RmtdAmt', 'xs:element')
# ('RmtdAmt', 'xs:element')
# ('RmtdAmt', 'xs:element')
# ('Room', 'xs:element')
# ('Rsn', 'xs:element')
# ('Rsn', 'xs:element')
# ('Rspnsblty', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SchmeNm', 'xs:element')
# ('SeqNb', 'xs:element')
# ('SeqNb', 'xs:element')
# ('ServiceLevel8Choice', 'xs:complexType')
# ('SettlementDateTimeIndication1', 'xs:complexType')
# ('SettlementInstruction7', 'xs:complexType')
# ('SettlementMethod1Code', 'xs:simpleType')
# ('SettlementTimeRequest2', 'xs:complexType')
# ('SplmtryData', 'xs:element')
# ('SplmtryData', 'xs:element')
# ('Strd', 'xs:element')
# ('StrtNm', 'xs:element')
# ('StructuredRegulatoryReporting3', 'xs:complexType')
# ('StructuredRemittanceInformation16', 'xs:complexType')
# ('SttlmAcct', 'xs:element')
# ('SttlmInf', 'xs:element')
# ('SttlmMtd', 'xs:element')
# ('SttlmPrty', 'xs:element')
# ('SttlmTmIndctn', 'xs:element')
# ('SttlmTmReq', 'xs:element')
# ('SubDept', 'xs:element')
# ('SupplementaryData1', 'xs:complexType')
# ('SupplementaryDataEnvelope1', 'xs:complexType')
# ('SvcLvl', 'xs:element')
# ('SvcLvl', 'xs:element')
# ('Tax', 'xs:element')
# ('TaxAmount2', 'xs:complexType')
# ('TaxAmountAndType1', 'xs:complexType')
# ('TaxAmountType1Choice', 'xs:complexType')
# ('TaxAmt', 'xs:element')
# ('TaxAmt', 'xs:element')
# ('TaxAmt', 'xs:element')
# ('TaxAuthorisation1', 'xs:complexType')
# ('TaxId', 'xs:element')
# ('TaxId', 'xs:element')
# ('TaxInformation7', 'xs:complexType')
# ('TaxInformation8', 'xs:complexType')
# ('TaxParty1', 'xs:complexType')
# ('TaxParty2', 'xs:complexType')
# ('TaxPeriod2', 'xs:complexType')
# ('TaxRecord2', 'xs:complexType')
# ('TaxRecordDetails2', 'xs:complexType')
# ('TaxRecordPeriod1Code', 'xs:simpleType')
# ('TaxRmt', 'xs:element')
# ('TaxTp', 'xs:element')
# ('TaxTp', 'xs:element')
# ('TaxblBaseAmt', 'xs:element')
# ('ThrdRmbrsmntAgt', 'xs:element')
# ('ThrdRmbrsmntAgtAcct', 'xs:element')
# ('TillTm', 'xs:element')
# ('Titl', 'xs:element')
# ('ToDt', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('Tp', 'xs:element')
# ('TrueFalseIndicator', 'xs:simpleType')
# ('TtlAmt', 'xs:element')
# ('TtlIntrBkSttlmAmt', 'xs:element')
# ('TtlTaxAmt', 'xs:element')
# ('TtlTaxAmt', 'xs:element')
# ('TtlTaxblBaseAmt', 'xs:element')
# ('TtlTaxblBaseAmt', 'xs:element')
# ('TwnLctnNm', 'xs:element')
# ('TwnNm', 'xs:element')
# ('TxId', 'xs:element')
# ('UETR', 'xs:element')
# ('UUIDv4Identifier', 'xs:simpleType')
# ('UltmtCdtr', 'xs:element')
# ('UltmtDbtr', 'xs:element')
# ('UltmtDbtr', 'xs:element')
# ('Ustrd', 'xs:element')
# ('XchgRate', 'xs:element')
# ('Yr', 'xs:element')
# ('xs:NOTATION', 'xs:primitiveType')
# ('xs:QName', 'xs:primitiveType')
# ('xs:anyURI', 'xs:primitiveType')
# ('xs:base64Binary', 'xs:primitiveType')
# ('xs:boolean', 'xs:primitiveType')
# ('xs:byte', 'xs:primitiveType')
# ('xs:date', 'xs:primitiveType')
# ('xs:dateTime', 'xs:primitiveType')
# ('xs:decimal', 'xs:primitiveType')
# ('xs:double', 'xs:primitiveType')
# ('xs:duration', 'xs:primitiveType')
# ('xs:float', 'xs:primitiveType')
# ('xs:gDay', 'xs:primitiveType')
# ('xs:gMonth', 'xs:primitiveType')
# ('xs:gMonthDay', 'xs:primitiveType')
# ('xs:gYear', 'xs:primitiveType')
# ('xs:gYearMonth', 'xs:primitiveType')
# ('xs:hexBinary', 'xs:primitiveType')
# ('xs:int', 'xs:primitiveType')
# ('xs:integer', 'xs:primitiveType')
# ('xs:negativeInteger', 'xs:primitiveType')
# ('xs:nonNegativeInteger', 'xs:primitiveType')
# ('xs:nonPositiveInteger', 'xs:primitiveType')
# ('xs:positiveInteger', 'xs:primitiveType')
# ('xs:short', 'xs:primitiveType')
# ('xs:string', 'xs:primitiveType')
# ('xs:time', 'xs:primitiveType')
# ('xs:unsignedByte', 'xs:primitiveType')
# ('xs:unsignedInt', 'xs:primitiveType')
# ('xs:unsignedLong', 'xs:primitiveType')
# ('xs:unsignedShort', 'xs:primitiveType')
# 100

# %%
resolver_df[85:]
# Out:
#                                                 0  \
# Max4Text                      xs:simpleType  True
# Max70Text                     xs:simpleType  True
# NamePrefix2Code               xs:simpleType  True
# Number                        xs:simpleType  True
# PercentageRate                xs:simpleType  True
# PhoneNumber                   xs:simpleType  True
# PreferredContactMethod1Code   xs:simpleType  True
# Priority2Code                 xs:simpleType  True
# Priority3Code                 xs:simpleType  True
# RegulatoryReportingType1Code  xs:simpleType  True
# RemittanceLocationMethod2Code xs:simpleType  True
# SettlementMethod1Code         xs:simpleType  True
# TaxRecordPeriod1Code          xs:simpleType  True
# TrueFalseIndicator            xs:simpleType  True
# UUIDv4Identifier              xs:simpleType  True
#
#                                                                             1
# Max4Text                      xs:simpleType   [(xs:string, xs:primitiveType)]
# Max70Text                     xs:simpleType   [(xs:string, xs:primitiveType)]
# NamePrefix2Code               xs:simpleType   [(xs:string, xs:primitiveType)]
# Number                        xs:simpleType  [(xs:decimal, xs:primitiveType)]
# PercentageRate                xs:simpleType  [(xs:decimal, xs:primitiveType)]
# PhoneNumber                   xs:simpleType   [(xs:string, xs:primitiveType)]
# PreferredContactMethod1Code   xs:simpleType   [(xs:string, xs:primitiveType)]
# Priority2Code                 xs:simpleType   [(xs:string, xs:primitiveType)]
# Priority3Code                 xs:simpleType   [(xs:string, xs:primitiveType)]
# RegulatoryReportingType1Code  xs:simpleType   [(xs:string, xs:primitiveType)]
# RemittanceLocationMethod2Code xs:simpleType   [(xs:string, xs:primitiveType)]
# SettlementMethod1Code         xs:simpleType   [(xs:string, xs:primitiveType)]
# TaxRecordPeriod1Code          xs:simpleType   [(xs:string, xs:primitiveType)]
# TrueFalseIndicator            xs:simpleType  [(xs:boolean, xs:primitiveType)]
# UUIDv4Identifier              xs:simpleType   [(xs:string, xs:primitiveType)]

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [25], line 1
# ----> 1 assert False
#
# AssertionError:

# %%
from datetime import datetime, timedelta

datetime.now()-timedelta(days=41)

# %%
import uuid
str(uuid.uuid1())

# %%
pd.DataFrame(named_other_things).groupby(1).agg(len)

# %%
pd.DataFrame(named_other_things)[2][0]

# %%
assert False

# %%
pd.DataFrame(all_named_types)

# %%
# Identify both named and anonymous type definitions
# Those definitions that contain multi-part objects (sequences, choices, all's)
# can be considered object definitions. 
# How they nest will describe how those objects (entities) are linked to one another. 
type_objs={}
for p in TreePath._iterPaths(cust_tp.data):
    
    if p[-1] in type_definition_set:
        if "@name" in access_dict(cust_tp.data,p[:-1]).keys():
            # Some parent element or thing is referencing this local type
            # for the type's name, use the name of the referring object + _local

            type_objs[access_dict(cust_tp.data,p[:-1]+["@name"])+f"__local"]=(p,access_dict(cust_tp.data,p))
        else:

            tname=str(uuid.uuid1())+"b"
            type_objs[tname]=(p,access_dict(cust_tp.data,p))
    elif isnumeric(p[-1]) and p[-2] in type_definition_set:
            if "@name" in access_dict(cust_tp.data,p).keys():

                type_objs[access_dict(cust_tp.data,p+["@name"])]=(p,access_dict(cust_tp.data,p))
            else:

                tname=str(uuid.uuid1())+"a"
                type_objs[tname]=(p,access_dict(cust_tp.data,p))
            thing_type = p[-1]

# %%
type_objs.keys()

# %%
for k,v in type_objs.items():
    print(k)
    print("\t", v[0])
    print( len(v[1]))
    if len(v[1])<=2:
        print (json.dumps(v[1], indent=4))
    print()
    print()
    print()

# %%
access_dict(cust_tp.data,['xs:schema', 'xs:element', 1])

# %%
return_longest_matching_ancestor(['xs:schema', 'xs:element', 1, 'xs:complexType'],  named_nodes)

# %%
assert False

# %%
    referred_things=gen_labelled_path_dict(cust_tp.data, index_tag="@ref")

    for n, paths in referred_things.items():
        for p in paths:
            #print(p)
            name = n
            obj=access_dict(cust_tp.data, p[1])
            org=access_dict(cust_d, p[1])
            print(n, p[0], p[1], obj, org)

# %%
cust_tp.data

# %%
referred_things

# %%
assert False

# %%
access_dict(cust_d, named_things.get('test_by_reference')[0][1][:-2])

# %%
cust_d

# %%
access_dict(cust_d, named_things.get( 'Document')[0])

named_things.get( 'Document')

# %%
named_things.get('root')[0]
#access_dict(cust_d, named_things.get( 'root')[0][:-1])

# %%
build_path_index(cust_d, index_tag="@ref")

# %%
for k,v_list in things_requiring_reference.items():
    print(k,v_list)
    for e,v in enumerate(v_list):
        print(e)
        ref_path = return_closest_path_match(named_things,k,v)
        #print(v, ref_path)
        cust_tp.set(v, access_dict(cust_d, ref_path))
    print()

# %%
cust_tp.data

# %%
t_i = build_path_index(cust_d,"@name")

{k:[access_dict(cust_d, q) for q in v] for k,v in t_i.items()}

test_path = ['xs:schema', 'xs:complexType', 1,'xs:element', 1, 1, 1, 2, 'xs:complexType', 'xs:complexContent']

return_closest_path_match(t_i, "element5", test_path)

# %%
TreePath._shortest_common_path([t_i.get("element5")[0], test_path])

# %%
named_things

# %%
t_i['element5']

# %%
# 2) Classify the things:
c_dict={}
df_records=[]
for path in named_things:
    thing_name = access_dict(cust_d, path + ["@name"])
    # Does this thing have a type?
    if "@type" in access_dict(cust_d, path).keys():
        thing_type = access_dict(cust_d, path + ["@type"])
    else:
        thing_type = None
    # Does this thing reference a type via an extension or restriction "base"?
    if any([n in ('xs:restriction', 'xs:extension') for n in access_dict(cust_d, path).keys()]):
        base_context = [n for n in access_dict(cust_d, path).keys() if n in ('xs:restriction', 'xs:extension') ][0]
        thing_base = access_dict(cust_d, path+[base_context, '@base'])
    elif any([n in ('xs:simpleContent', 'xs:complexContent') for n in access_dict(cust_d, path).keys()]):
        content_type=[n for n in access_dict(cust_d, path).keys() if n in ('xs:simpleContent', 'xs:complexContent')][0]
        base_context = [n for n in access_dict(cust_d, path+[content_type]).keys() if n in ('xs:restriction', 'xs:extension') ][0]
        thing_base = access_dict(cust_d, path+[content_type, base_context, '@base'])
    else:
        content_type =None
        base_context = None
        thing_base = None
    # Does this thing contain one of the container types that might point to multiple elements?
    if any([n in ('xs:all', 'xs:group', 'xs:choice','xs:sequence') for n in access_dict(cust_d, path).keys()]):
        thing_contains_collection = True
    else:
        thing_contains_collection = False
        
    # What is this thing's parent object class? 
    if isnumeric(path[-1]):
        thing_expression_type = path[-2]
    else:
        thing_expression_type = path[-1]
    # Build a counter of parent expression types 
    if thing_expression_type in c_dict.keys():
        c_dict[thing_expression_type]=c_dict[thing_expression_type]+1
    else:
        c_dict[thing_expression_type]=1
    
    # Print some things
    df_records.append((thing_name, thing_type, thing_expression_type, thing_base, base_context, thing_contains_collection, content_type))
    
xsd_df = pd.DataFrame(df_records, columns=["Name", "Type", "expression_type", "base", "base_context", "has_collection", "content_type"])
xsd_df

# %%
xsd_df[xsd_df[["expression_type", "content_type"]].isnull().apply(lambda x : not any([y for y in x]), axis=1)]

# %%
c_dict

# %%
# 2) Classify the things:
typed_collection = {}
for path in named_things:
    thing_name = access_dict(cust_d, path + ["@name"])
    if isnumeric(path[-1]):
        thing_type = path[-2]
    else:
        thing_type = path[-1]
    if thing_type in typed_collection.keys():
        typed_collection[thing_type].append(path)
    else:
        typed_collection[thing_type]=[path]
    print (path,  thing_name, thing_type)

# %%
path=['xs:schema', 'xs:complexType', 2, 'xs:complexContent', 'xs:extension', 'xs:attribute']
access_dict(cust_d, path)

# %%
[access_dict(cust_d, path) for path in chain(*typed_collection.values())]

# %%
# Of the named things extracted, what are their parent types?
{k:len(v) for k,v in typed_collection.items()}

# %%
# Of the things extracted, which are terminal items?
terminals = {s for s in primitives_set}
log=[]
for k,v in typed_collection.items():
    print(k)
    for path in v:
        node = access_dict(cust_d, path)
        if "@type" in node.keys():
            if (node['@type'] in terminals):
                log.append(k)
                terminals.add(node["@name"])
            else:
                print(k, "no terminal")
        if "xs:restriction" in node.keys():
            if node["xs:restriction"]["@base"] in terminals:
                
                terminals.add(node["@name"])
                log.append(k)
            else:
                print(k, "no terminal")
        
log

# %%
for k,v in typed_collection.items():
    
    if k == "xs:complexType":
        for path in v:
            node = access_dict(cust_d, path)
            if "xs:sequence" in node.keys():
                print(node["@name"])
                if 'xs:element' in node['xs:sequence'].keys():
                    print (len(node['xs:sequence']['xs:element']))
                    print (type(node['xs:sequence']['xs:element']))
                    if isinstance(node['xs:sequence']['xs:element'], list):
                        for h,i in node['xs:sequence'].items():
                            for si in i:
#                                print(si)
                                print("\t", str(si["@name"]), "<" + si["@type"] + ">")
                    else:
                        si = node['xs:sequence']['xs:element']
#                        print(si)
                        print("\t", str(si["@name"]), "<" + si["@type"] + ">")

            print()
            print()

# %%
class TypeDefinition(object):
    def __init__(self, type_dict):
        if "@name" in type_dict.keys():
            self.name = type_dict['@name']
        else:
            assert False
        if "@id" in type_dict.keys():
            self.id = type_dict['@id']
        self.children=[]
            
    def parse_restriction(self, type_dict):
        if "xs:restriction" in type_dict.keys():
            if "@base" in type_dict['xs:restriction'].keys():
                self.children.append ( type_dict['xs:restriction']['@base'])
                
    def parse_extension(self, type_dict):
        if "xs:extension" in type_dict.keys():
            if "@base" in type_dict['xs:extension'].keys():
                self.children.append ( type_dict['xs:extension']['@base'])
                
    def parse_all(self, type_dict):
        if "xs:all" in type_dict.keys():
            for e in type_dict['xs:all']:
                self.parse_element(e)
        
    def parse_group(self, type_dict):
        
    def parse_sequence(self, type_dict):
        
    def parse_choice(self, type_dict):
        
    def parse_attribute(self, type_dict):
        
    def parse_attribute_group(self, type_dict):
        
    def parse_simple_content(self, type_dict):

    def parse_complex_content(self, type_dict):

    def parse_union(self, type_dict):
        if "xs:union" in type_dict.keys():
            if "@memberTypes" in type_dict['xs:union'].keys():
                self.children.append ( type_dict['xs:list']["@memberTypes"] )
                
    def parse_list(self, type_dict):
        if "xs:list" in type_dict.keys():
            if "@itemType" in type_dict['xs:list'].keys():
                self.children.append ( type_dict['xs:list']["@itemType"] )
                
    def parse_element(self, type_dict):
        
        
class SimpleType(TypeDefinition):
    
    def __init__(self, type_dict):
        
        super().__init__(type_dict)

            
    def __repr__(self):
        return str(self.name) + ":<" + str(self.base) + ">(primitive:" + str(self.primitive) + ")"
    
class ComplexType(TypeDefinition):
    
    def __init__(self, type_dict):
        
        super().__init__(type_dict)
            
            
    def __repr__(self):
        return str(self.name) + ":<" + str(None) + ">"

# %%
[(p, access_dict(cust_d, p)) for p in typed_collection['xs:element']]

# %%
[(p, access_dict(cust_d, p)) for p in typed_collection['xs:element']]

# %%
k=['xs:schema', 'xs:complexType', 20]
reduce(operator.getitem, k, cust_d)

# %%
k=['xs:schema', 'xs:complexType', 88]
reduce(operator.getitem, k, cust_d)

# %%
Counter({tuple(k):reduce(operator.getitem, k, cust_d)  for k in leaves if k[-1]=="@name"}.values())

# %%
cust_d

# %%
raw_names_d, raw_bases_d, raw_types_d, raw_primitives_d, raw_primitives_labels_d, ref_keys, specification_d = xsdparse.parse_xsd(customer_xsd)

# %%
reduce(operator.getitem, ['xs:schema', 'xs:complexType', 2], cust_d)

# %%
xsdparse.build_(specification_d.get("customerinfo")[0],specification_d)

# %%
ref_keys

# %%
"""
xsdparse
===========

A utility for parsing an xsd and producing a model specification.

"""
import xmltodict
import zipfile
from collections import Counter
import os, sys
sys.path.append(os.path.abspath("../treepath"))
import treepath.treepath as tp

import pandas as pd
import networkx as nx


def key_scan_obj(obj, search=None, path=None, results=None):
    if results is None:
        results = []
    if search is None:
        search = None
    if path is None:
        path = []
    if isinstance(obj, dict):
        for k,v in obj.items():
            if (k==search or v==search):
                results.append({"path" : path+[k], "value" : v})
            elif isinstance(v, (dict, list)):
                results.extend(key_scan_obj(v, search=search, path=path + [k]))
    elif isinstance(obj, list):
        for e,v in enumerate(obj):
            if v==search:
                results.append({"path" : path+[e], "value" : v})
            elif isinstance(v, (dict, list)):
                results.extend(key_scan_obj(v, search=search, path = path + [e]))
    else:
        if v==search or search is None:
            results.append({"path" : path, "value" : v})
    return results

prims=[ {'@name': 'xs:duration'},
        {'@name': 'xs:dateTime'},
        {'@name': 'xs:time'},
        {'@name': 'xs:date'},
        {'@name': 'xs:gYearMonth'},
        {'@name': 'xs:gYear'},
        {'@name': 'xs:gMonthDay'},
        {'@name': 'xs:gDay'},
        {'@name': 'xs:gMonth'},
        {'@name': 'xs:string'},
        {'@name': 'xs:boolean'},
        {'@name': 'xs:base64Binary'},
        {'@name': 'xs:hexBinary'},
        {'@name': 'xs:float'},
        {'@name': 'xs:decimal'},
        {'@name': 'xs:integer'},
        {'@name': 'xs:nonPositiveInteger'},
        {'@name': 'xs:negativeInteger'},
        {'@name': 'xs:int'},
        {'@name': 'xs:short'},
        {'@name': 'xs:byte'},
        {'@name': 'xs:nonNegativeInteger'},
        {'@name': 'xs:unsignedLong'},
        {'@name': 'xs:positiveInteger'},
        {'@name': 'xs:unsignedInt'},
        {'@name': 'xs:unsignedShort'},
        {'@name': 'xs:unsignedByte'},
        {'@name': 'xs:double'},
        {'@name': 'xs:anyURI'},
        {'@name': 'xs:QName'},
       {'@name': 'xs:NOTATION'},
]
def extract_paths(tree, search_val, path_offset, filter_offset=None, filter_value=None):
    if filter_offset is not None and filter_value is not None:
        extract = [(tuple(k['path'][:path_offset]), k['value']) for k in key_scan_obj(tree, search_val) if k['path'][filter_offset].lower()==filter_value]
    else:
        extract = [(tuple(k['path'][:path_offset]), k['value']) for k in key_scan_obj(tree, search_val) ]
    return extract


def parse_xsd(xsd_bytes):
    xsd_d = xmltodict.parse(xsd_bytes)
    xsd_d['xs:schema']['xs:primitiveType']=prims
    raw_names_d = dict(extract_paths(xsd_d['xs:schema'], "@name", -1))
    raw_bases_d = dict(extract_paths(xsd_d['xs:schema'], "@base", -2, -2, 'xs:restriction') + extract_paths(xsd_d['xs:schema'], "@base", -3, -2, 'xs:extension'))
    raw_types_d = dict(extract_paths(xsd_d['xs:schema'], "@type", -1))
    raw_primitives_d = dict(extract_paths(xsd_d['xs:schema'], "@base", -1, 0, 'xs:primitiveType'))
    raw_primitives_labels_d = {k:"_terminal_" for k,v in raw_primitives_d.items()}

    refs_d = dict([(k,v) for k,v in raw_names_d.items() if not any([p in ['xs:element','xs:attribute'] for p in k[-2:]])])

    # This contains all the specifications required to build the model, keys, (names, types, contextual_clues) TBD: Cardinalities
    specification_d = {k:(v,
                      raw_types_d.get(k, raw_bases_d.get(k,raw_primitives_labels_d.get(k,"_container_"))),
                      "_ref_" if k in refs_d.keys() else "_spec_") for k,v in raw_names_d.items()}

    ref_keys = {v[0]:(k,v[1],v[2]) for k,v in specification_d.items() if v[2]=='_ref_'}
    return raw_names_d, raw_bases_d, raw_types_d, raw_primitives_d, raw_primitives_labels_d, ref_keys, specification_d


def build_(root, spec_d, obj=None):
    ref_keys = {v[0]:(k,v[1],v[2]) for k,v in spec_d.items() if v[2]=='_ref_'}
    if obj is None:
        obj={}
    name, v_type, clue = spec_d.get(root)
    #print(root, name, v_type, clue)
    #print()
    content=[]
    if clue == '_ref_':
        #print("R")
        if v_type == "_container_":
            #print("C")
            for k in spec_d.keys():
                if k[0:len(root)]==root and k!=root:
                    content.append(build_(k, spec_d))
        elif v_type != "_container_" and v_type != "_terminal_":
            #print("!", v_type, clue)
            lookahead = ref_keys.get(v_type)
            if lookahead[1] == "_terminal_":
                content={v_type:{}}
            else:
                content=build_( lookahead[0], spec_d)
        else:
            content=name
    elif clue == '_spec_':

        #print (name, v_type, ref_keys.get(v_type))
        content=build_( ref_keys.get(v_type)[0], spec_d)

    else:
        assert False
        return name, v_type, clue
    obj[name]=content
    return obj

# %%
# Resolve References
# Loop over the data, taking references where they exist and replacing them with their
# de-referenced lookup values
i=0
finished=False

cust_tp = tp.TreePath(cust_d)

while not finished:
    i = i + 1
    things_requiring_reference = build_path_index(cust_tp.data, index_tag="@ref")
    copy_tp = tp.TreePath(cust_tp.data)
    if len(things_requiring_reference)==0:
        finished=True
        break

    for k,v_list in things_requiring_reference.items():
#        print(k,v_list)
        for e,v in enumerate(v_list):
#            print("\t", e)
            ref_path = return_closest_path_match(named_things,k,v)
#            print("`",v,"`", ref_path)
            retain_content_d={ki:vi for ki,vi in access_dict(copy_tp.data, v).items() if ki != "@ref"}
            cust_tp.set(v, {**retain_content_d, **access_dict(copy_tp.data, ref_path[1])})
    print(i,len(things_requiring_reference))
#k,access_dict(cust_d, things_requiring_reference[k])

# %%
xsd_construct = parse_xsd(customer_xsd)

# %%
q = build_(('xs:element',), xsd_construct[6])

# %%
paths = traverse_object(q)

# %%
for p in paths[0:25]:
    print (p[-8:], len(p))
